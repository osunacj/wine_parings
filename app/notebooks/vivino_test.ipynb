# %%
import datetime
import pandas as pd

df = pd.read_csv('./../data/vivino_wines.csv')

# %%
len(df)
# Out:
# 89662

# %%
df.head(5)
# Out:
#                           name  year vintage_id       id ratings score  \
# 0  Franciacorta Cuvée Prestige  N.V.  164943083  1191278   25682   4.1
# 1                  Trento Brut  N.V.    1749818  1367887   24491   3.8
# 2           Classic Cuvee Brut   NaN    2093215  1397132   15181   4.2
# 3                   Chardonnay  2021  167609441  1244627   15137   3.8
# 4                    Cava Brut  N.V.  164942632  1151570   14833   3.5
#
#            status             region         country         winery  \
# 0          Normal       Franciacorta           Italy  Ca' del Bosco
# 1          Normal             Trento           Italy        Ferrari
# 2          Normal             Sussex  United Kingdom      Nyetimber
# 3  BelowThreshold  Casablanca Valley           Chile         Montes
# 4          Normal               Cava           Spain    Jaume Serra
#
#                                              flavors  \
# 0  apple, pear, peach, green apple, apricot, yell...
# ...

# %%
df.iloc[:20000].to_csv('./../data/vivino_wines_reduced.csv', mode='w', index=False)

# %%
df = pd.read_csv('./../data/vivino_wines_reduced.csv')

# %%
len(df)
# Out:
# 20000
