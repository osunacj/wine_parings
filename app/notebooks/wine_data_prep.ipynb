# %%
import os
import pandas as pd
import numpy as np
import spacy


from matplotlib import pyplot as plt
from tqdm import tqdm
from helpers.prep.foodbert_norm import RecipeNormalizer
from gensim.models.phrases import Phrases, Phraser
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import nltk
import string

# nltk.download('stopwords')

BASE_PATH = "../data/wine_extracts"

# %%
i = 0
wine_dataframe = pd.DataFrame()
for file in os.listdir(BASE_PATH):
    file_location = BASE_PATH + '/' + str(file)
    if i==0:
        wine_dataframe = pd.read_csv(file_location)
        i+=1
    else:
        df_to_append = pd.read_csv(file_location, low_memory=False, encoding='latin-1')
        wine_dataframe = pd.concat([wine_dataframe, df_to_append], axis=0)

wine_dataframe.drop_duplicates(subset=['Name'], inplace=True)

geographies = ['Subregion', 'Region', 'Province', 'Country']

for geo in geographies:
    wine_dataframe[geo] = wine_dataframe[geo].apply(lambda x : str(x).strip())

print(wine_dataframe.shape)
# Out:
# (143686, 22)

# %%
wine_dataframe.head(3)
# Out:
#    Unnamed: 0 Alcohol          Appellation Bottle Size Category  Country  \
# 0       791.0      9%  Burgenland, Austria      375 ml  Dessert  Austria
# 1       792.0  10.50%  Burgenland, Austria      375 ml  Dessert  Austria
# 2       796.0      9%  Burgenland, Austria      375 ml  Dessert  Austria
#
#   Date Published                                        Description  \
# 0      12/1/2018  Marmalade, toffee, vanilla and tonka bean swir...
# 1      12/1/2018  A touch of creaminess on the nose leads to a m...
# 2      12/1/2018  A smokiness lies thickly above the apple fruit...
#
#                                     Designation                     Importer  \
# 0  Nouvelle Vague Trockenbeerenauslese Nummer 7  Terlato Wines International
# 1          Trockenbeerenauslese Grand Selection                   GD Imports
# 2                          Trockenbeerenauslese          Blue Danube Wine Co
#
#    ...    Province Rating Region           Reviewer Reviewer Twitter Handle  \
# 0  ...  Burgenland   98.0    nan  Anne KrebiehlÂ MW             @AnneInVino
# 1  ...  Burgenland   97.0    nan  Anne KrebiehlÂ MW             @AnneInVino
# 2  ...  Burgenland   96.0    nan  Anne KrebiehlÂ MW             @AnneInVino
#
#   Subregion                  User Avg Rating     Variety Vintage  \
# 0       nan  Not rated yet [Add Your Review]  Chardonnay  2015.0
# 1       nan  Not rated yet [Add Your Review]  Chardonnay  2015.0
# 2       nan  Not rated yet [Add Your Review]  Chardonnay  2015.0
#
#             Winery
# 0          Kracher
# 1  H.& C. Nittnaus
# 2         Rosenhof
#
# [3 rows x 22 columns]

# %%
wine_dataframe.columns
# Out:
# Index(['Unnamed: 0', 'Alcohol', 'Appellation', 'Bottle Size', 'Category',
#        'Country', 'Date Published', 'Description', 'Designation', 'Importer',
#        'Name', 'Price', 'Province', 'Rating', 'Region', 'Reviewer',
#        'Reviewer Twitter Handle', 'Subregion', 'User Avg Rating', 'Variety',
#        'Vintage', 'Winery'],
#       dtype='object')

# %%
wine_dataframe.iloc[2]
# Out:
# Unnamed: 0                                                             796.0
# Alcohol                                                                   9%
# Appellation                                              Burgenland, Austria
# Bottle Size                                                           375 ml
# Category                                                             Dessert
# Country                                                              Austria
# Date Published                                                     12/1/2018
# Description                A smokiness lies thickly above the apple fruit...
# Designation                                             Trockenbeerenauslese
# Importer                                                 Blue Danube Wine Co
# Name                       Rosenhof 2015 Trockenbeerenauslese Chardonnay ...
# Price                                                                   $29
# Province                                                          Burgenland
# Rating                                                                  96.0
# Region                                                                   nan
# Reviewer                                                   Anne KrebiehlÂ MW
# Reviewer Twitter Handle                                          @AnneInVino
# Subregion                                                                nan
# User Avg Rating                              Not rated yet [Add Your Review]
# Variety                                                           Chardonnay
# Vintage                                                               2015.0
# Winery                                                              Rosenhof
# Name: 2, dtype: object

# %%
all_wine_corpus = ' '.join(str(sentence).lower() for sentence in wine_dataframe.Description.to_numpy()[:5000])
wine_sentences_tokenized = sent_tokenize(all_wine_corpus)
stop_words = set(stopwords.words('english')) 
term_normalizer = RecipeNormalizer()

all_corpus_by_word = []
for sentence in wine_sentences_tokenized:
    sent = []
    for word in word_tokenize(sentence):
        if word not in stop_words and word.isalpha():
            sent.append(word)
    all_corpus_by_word.append(sent)

words_in_corpus = [word for sentence in all_corpus_by_word for word in sentence]
terms = term_normalizer.normalize_ingredients(
    words_in_corpus
)

pd.Series(list(dict.fromkeys(words_in_corpus))).to_csv('../data/produce/wine_terms.csv')
# Out:
# 100%|██████████| 115380/115380 [02:22<00:00, 811.42it/s]

# %%
previous_idx = 0
normalized_corpus_by_words = []
for sentence in all_corpus_by_word:
    length = len(sentence)
    new_index = previous_idx + length
    normalized_corpus_by_words.append(terms[previous_idx:new_index])
    previous_idx = new_index

# %%
assert len(normalized_corpus_by_words) == len(all_corpus_by_word)

# %%
wine_bigram_model = Phrases(normalized_corpus_by_words, min_count=10)
wine_bigrams = [wine_bigram_model[line] for line in all_corpus_by_word]

# %%
wine_bigrams
# Out:
# [['marmalade', 'toffee', 'vanilla', 'tonka', 'bean', 'swirl', 'nose'],
#  ['rich',
#   'smooth',
#   'rounded',
#   'mellow',
#   'yet',
#   'incredibly',
#   'bright',
#   'aromatic',
#   'core',
#   'fine',
#   'citrus'],
#  ['think', 'dried', 'candied', 'orange_peel', 'candied', 'blood', 'orange'],
#  ['magical',
#   'balance',
#   'citrus',
#   'freshness',
#   'strikes',
#   'cushioning',
#   'gentle',
#   'vanilla'],
#  ['textural', 'bliss', 'aromatic', 'fireworks'],
#  ['drink', 'least'],
#  ['touch',
#   'creaminess',
#   'nose',
#   'leads',
#   'mellow',
#   'palate',
#   'full',
#   'honeyed',
#   'baked',
#   'apple',
#   'fruit'],
#  ['hint',
#   'vanilla',
#   'bright',
#   'almost',
#   'piercing',
#   'gleam',
#   'wonderful',
#   'lemon',
#   'sharpness',
#   'putting',
#   'creamy',
#   'decadence',
#   'palate',
#   'even',
#   'focus'],
#  ['ultimate', 'concentration', 'finishes', 'zesty', 'vigor'],
#  ['built', 'last'],
#  ['drink', 'least'],
#  ['smokiness',
#   'lies',
#   'thickly',
#   'apple',
#   'fruit',
#   'notes',
#   'heady',
#   'tba',
#   'glossing',
#   'everything',
#   'darker',
#   'brooding',
#   'presence'],
#  ['smoky',
#   'darkness',
#   'hovers',
#   'palate',
#   'spiky',
#   'bright',
#   'spur',
#   'lemon',
#   'freshness',
#   'breaks',
#   'triumphantly',
#   'lending',
#   'drive',
#   'precision',
#   'apricot',
#   'mirabelle',
#   'plum',
#   'fruit',
#   'spreads',
#   'lusciousness',
#   'across',
#   'tongue'],
#  ['rich', 'concentrated', 'intense', 'beautifully', 'unusual'],
#  ['drink', 'least'],
#  ['lime',
#   'blossom',
#   'tea',
#   'candied',
#   'apple',
#   'alluring',
#   'edge',
#   'smoke',
#   'lend',
#   'extra',
#   'dimensions',
#   'nose'],
#  ['palate',
#   'brings',
#   'forth',
#   'full',
#   'force',
#   'luscious',
#   'concentrated',
#   'botrytis',
#   'generous',
#   'sweetness',
#   'bundled',
#   'force',
#   'balancing',
#   'spicy',
#   'freshness'],
#  ['possesses', 'wonderful', 'balance', 'leaves', 'lasting', 'sweetness'],
#  ['made',
#   'method',
#   'dessert',
#   'wine',
#   'balanced',
#   'smooth',
#   'interwoven',
#   'layers',
#   'celebration',
#   'salted',
#   'caramel',
#   'green_apple',
#   'dried',
#   'apricot'],
#  ['sweet',
#   'rich',
#   'classically',
#   'reward',
#   'blue',
#   'cheeses',
#   'spiced',
#   'nuts'],
#  ['potential', 'regional', 'dessert', 'wine'],
#  ['aromas',
#   'honeysuckle',
#   'ripe',
#   'asian_pear',
#   'gala_apple',
#   'lead',
#   'palate',
#   'honey',
#   'glaze',
#   'lemongrass',
#   'pear',
#   'syrup'],
#  ['fresh', 'sipper'],
#  ['stone', 'earth', 'pear', 'show', 'nose'],
#  ['palate',
#   'joins',
#   'bittersweet',
#   'notion',
#   'recalls',
#   'dried',
#   'pear',
#   'skin',
#   'dried',
#   'orange_rind'],
#  ['body', 'remains', 'light', 'flavors', 'anchored', 'deeply', 'earthily'],
#  ['made', 'balanced', 'style', 'finish', 'dreamy', 'salty', 'cheese'],
#  ['notes', 'linden', 'tea', 'candied', 'lemon', 'hit', 'nose'],
#  ['palate',
#   'comes',
#   'gentle',
#   'sweetness',
#   'balanced',
#   'delicate',
#   'fresh',
#   'acidity'],
#  ['unusual', 'style', 'shows', 'demerara', 'sugar', 'notes'],
#  ['sweet',
#   'enough',
#   'dessert',
#   'wine',
#   'shine',
#   'either',
#   'spicy',
#   'asian',
#   'dishes',
#   'cheese'],
#  ['golden',
#   'dessert',
#   'chardonnay',
#   'opens',
#   'soft',
#   'aromas',
#   'papaya',
#   'melon',
#   'squash',
#   'corn'],
#  ['palate', 'chunky', 'like', 'pineapple', 'syrup'],
#  ['flavors',
#   'pineapple',
#   'melon',
#   'mango',
#   'puree',
#   'end',
#   'note',
#   'carrot',
#   'long',
#   'viscous',
#   'finish'],
#  ['intense',
#   'aromas',
#   'candied',
#   'orange_peel',
#   'honeycomb',
#   'accented',
#   'pollen',
#   'spice',
#   'nose',
#   'rich',
#   'ice',
#   'wine'],
#  ['palate',
#   'sunny',
#   'plush',
#   'marked',
#   'sunny',
#   'acidity',
#   'ripe',
#   'yellow',
#   'apple',
#   'tangerine',
#   'flavors'],
#  ['lingering',
#   'thread',
#   'bitter',
#   'cardamom',
#   'spice',
#   'lend',
#   'interest',
#   'finish'],
#  ['color', 'sweet', 'wine', 'deep', 'amber'],
#  ['aromas', 'savory', 'rich', 'flavors', 'unctuous', 'nutty'],
#  ['fun', 'drink', 'tastes', 'like', 'mature', 'wine'],
#  ['typhoon', 'pabuk', 'drenched', 'valley', 'harvest', 'botrytised', 'grapes'],
#  ['making',
#   'lemonade',
#   'lemon',
#   'winery',
#   'grapes',
#   'crafted',
#   'ultrarich',
#   'dessert',
#   'wine'],
#  ['dense',
#   'flavors',
#   'butterscotch',
#   'sweet',
#   'lemon',
#   'candy',
#   'make',
#   'potent',
#   'combo'],
#  ['one', 'bottle', 'easily', 'satisfy', 'four', 'sweet', 'tooths'],
#  ['nose', 'uncertain', 'hovers', 'musky', 'botrytis', 'lactic', 'tartness'],
#  ['palate',
#   'removes',
#   'doubt',
#   'shines',
#   'luscious',
#   'concentrated',
#   'sweetness',
#   'referencing',
#   'pleasant',
#   'bitterness',
#   'honeycomb',
#   'spice',
#   'maple',
#   'syrup'],
#  ['pure', 'lemon', 'freshness', 'illuminates', 'everything'],
#  ['drink',
#   'lush',
#   'candied',
#   'fruits',
#   'abound',
#   'naturally',
#   'botrytised',
#   'wine'],
#  ['residual', 'sugar', 'still', 'reaches', 'alcohol'],
#  ['pineapple',
#   'lemon',
#   'orange_peel',
#   'pine',
#   'resin',
#   'honey',
#   'cedar',
#   'butterscotch',
#   'mix',
#   'plus',
#   'lot'],
#  ['go', 'spelunking', 'wine', 'never', 'see'],
#  ['made',
#   'chardonnay',
#   'viognier',
#   'una',
#   'thick',
#   'caramel',
#   'vanilla',
#   'tones',
#   'throughout'],
#  ['conveys',
#   'distinct',
#   'taste',
#   'aroma',
#   'burnt',
#   'sugar',
#   'like',
#   'pecans',
#   'roasting',
#   'open',
#   'fire'],
#  ['complex',
#   'works',
#   'finely',
#   'made',
#   'sweet',
#   'wine',
#   'ready',
#   'paired',
#   'fruity',
#   'desserts'],
#  ['orange_peel', 'distinct', 'aroma', 'otherwise', 'neutral', 'nose'],
#  ['soft',
#   'simple',
#   'palate',
#   'flavors',
#   'mango',
#   'sweet',
#   'lime',
#   'burnt',
#   'brown',
#   'sugar',
#   'caramel',
#   'lead',
#   'chunky',
#   'sugary',
#   'finish'],
#  ['hints',
#   'cream',
#   'vanilla',
#   'lend',
#   'warmth',
#   'savory',
#   'pressed',
#   'apples',
#   'pears',
#   'slightly',
#   'rustic',
#   'wine'],
#  ['rich', 'silky', 'palate', 'bright', 'pleasing', 'acidity'],
#  ['fresh',
#   'superripe',
#   'well',
#   'candied',
#   'pineapple',
#   'combine',
#   'give',
#   'utter',
#   'opulence',
#   'rich',
#   'viscous',
#   'wine'],
#  ['longer', 'taste', 'almost', 'tropical', 'flavors', 'become'],
#  ['ice',
#   'wine',
#   'untainted',
#   'botrytis',
#   'shines',
#   'purity',
#   'drive',
#   'astonishing',
#   'acidity',
#   'keeps',
#   'right',
#   'side',
#   'paradise'],
#  ['headiness',
#   'roasted',
#   'hazelnuts',
#   'bourbon',
#   'vanilla',
#   'blossom',
#   'honey',
#   'immense',
#   'seductive',
#   'power'],
#  ['palate', 'follows', 'precision', 'concentration', 'long', 'length'],
#  ['tba', 'mature', 'full', 'package', 'easily', 'charm', 'years', 'come'],
#  ['wild',
#   'thyme',
#   'moss',
#   'blaze',
#   'savory',
#   'trail',
#   'honeyed',
#   'sweetness',
#   'cut',
#   'wonderfully',
#   'precise',
#   'acidity'],
#  ['linear',
#   'superclean',
#   'wonderful',
#   'contrast',
#   'make',
#   'ba',
#   'winner',
#   'dessert',
#   'trolley',
#   'cheeseboard'],
#  ['wine', 'wonderful', 'balance', 'fresh', 'lemon', 'acidity', 'sweetness'],
#  ['honeyed',
#   'texture',
#   'cut',
#   'mineral',
#   'bite',
#   'gives',
#   'opulence',
#   'structure',
#   'time'],
#  ['wine',
#   'needs',
#   'long',
#   'aging',
#   'drink',
#   'wine',
#   'wonderful',
#   'spice',
#   'richness',
#   'dry',
#   'background'],
#  ['flavors',
#   'honey',
#   'noble',
#   'rot',
#   'fill',
#   'mouth',
#   'swathe',
#   'richness',
#   'opulence'],
#  ['wine',
#   'still_young',
#   'needs',
#   'age',
#   'drink',
#   'streaked',
#   'acidity',
#   'well',
#   'rich',
#   'sweet',
#   'fruits',
#   'full',
#   'rounded',
#   'yet',
#   'balanced',
#   'wine',
#   'fresh',
#   'flavors',
#   'honey',
#   'apricot'],
#  ['wine',
#   'could',
#   'age',
#   'drink',
#   'distinctive',
#   'wine',
#   'notes',
#   'reminiscent',
#   'freshly',
#   'made',
#   'apple',
#   'sauce'],
#  ['harvested',
#   'brix',
#   'sweet',
#   'flavor',
#   'concentration',
#   'quite',
#   'carry',
#   'way'],
#  ['luscious', 'opulent', 'essenz', 'purest', 'elixir'],
#  ['rich',
#   'texture',
#   'unctuous',
#   'smooth',
#   'honey',
#   'flavors',
#   'laced',
#   'intense',
#   'acidity'],
#  ['wine', 'tastes', 'delicious', 'acidity', 'allow', 'age', 'many', 'years'],
#  ['deep',
#   'golden',
#   'color',
#   'botrytized',
#   'chardonnay',
#   'boasts',
#   'residual',
#   'sugar',
#   'brix',
#   'picked',
#   'tastes',
#   'honeycomb',
#   'ripe',
#   'apricot'],
#  ['balanced', 'sickly', 'sweet'],
#  ['pour', 'gourmet', 'vanilla_bean', 'ice', 'cream', 'done'],
#  ['bold',
#   'gold',
#   'penetrating',
#   'aromas',
#   'orange',
#   'dried',
#   'apricots',
#   'sweat',
#   'honey',
#   'comb'],
#  ['feel',
#   'rich',
#   'layered',
#   'enough_acidity',
#   'lend',
#   'volume',
#   'apricot',
#   'dried',
#   'peach',
#   'honey',
#   'flavors',
#   'chardonnay',
#   'pushing'],
#  ['thick', 'bit', 'unctuous', 'finish', 'drink'],
#  ['balance',
#   'sweetness',
#   'acidity',
#   'delicious',
#   'wine',
#   'hints',
#   'honey',
#   'well',
#   'pear',
#   'ripe',
#   'melon'],
#  ['touch', 'wood', 'background', 'give', 'wine', 'complexity'],
#  ['smelling',
#   'like',
#   'apple_pie',
#   'wonderfully',
#   'smooth',
#   'golden',
#   'colored',
#   'chardonnay',
#   'voluptuous',
#   'sexy',
#   'rich',
#   'yet',
#   'overwhelming',
#   'perfectly',
#   'balanced',
#   'sweetness',
#   'alcohol'],
#  ['would',
#   'good',
#   'dry',
#   'cheese',
#   'tarte',
#   'tatin',
#   'also',
#   'stand',
#   'aplomb'],
#  ['nose',
#   'chardonnay',
#   'smells',
#   'almost',
#   'like',
#   'traditional',
#   'french',
#   'cider',
#   'sentiment',
#   'carries',
#   'flavor',
#   'though',
#   'wine',
#   'takes',
#   'much',
#   'richer',
#   'sweeter',
#   'tones'],
#  ['chunky', 'unfocused', 'aromas', 'tell', 'almost', 'need', 'know'],
#  ['wine', 'edgy', 'cidery', 'mustard', 'pickled', 'flavors'],
#  ['stalky', 'jumbled', 'finish'],
#  ['smoothest',
#   'ripest',
#   'wine',
#   'opulent',
#   'character',
#   'brought',
#   'touch',
#   'wood'],
#  ['rich',
#   'honey',
#   'edge',
#   'surrounded',
#   'ripe',
#   'mango_pineapple',
#   'light',
#   'touch',
#   'acidity'],
#  ['age', 'wine', 'several', 'years'],
#  ['becomes',
#   'sweet',
#   'wine',
#   'chardonnay',
#   'natural',
#   'richness',
#   'shows',
#   'immensely'],
#  ['wine',
#   'orange',
#   'crystallized',
#   'orange',
#   'flavors',
#   'along',
#   'intense',
#   'concentration'],
#  ['smooth', 'texture', 'given', 'right', 'lift', 'acidity'],
#  ['sweet', 'chardonnay', 'good', 'enticing'],
#  ['nose', 'clean', 'peach', 'melon', 'honeyed', 'aromas'],
#  ['palate', 'balanced', 'smooth', 'good', 'blend', 'stickiness', 'acidity'],
#  ['tastes', 'slightly', 'candied', 'melon', 'mango', 'flavors'],
#  ['good', 'chard', 'field', 'many', 'players'],
#  ['brilliant',
#   'wine',
#   'honey',
#   'intense',
#   'acidity',
#   'crispest',
#   'lemon',
#   'spice',
#   'flavors'],
#  ['chardonnay',
#   'grown',
#   'tatschler',
#   'vineyard',
#   'lively',
#   'fresh',
#   'sumptuous',
#   'time'],
#  ['number',
#   'really',
#   'good',
#   'dessert',
#   'wines',
#   'available',
#   'per',
#   'bottle',
#   'severely',
#   'limited',
#   'refreshing',
#   'ray',
#   'golden',
#   'sweetness'],
#  ['dried',
#   'apricots',
#   'add',
#   'enough',
#   'citrus',
#   'pith',
#   'partially',
#   'balance',
#   'intensely',
#   'sweet',
#   'flavors'],
#  ['drink', 'lusciousness', 'next', 'couple', 'years'],
#  ['marmalade',
#   'syrup',
#   'molasses',
#   'deep',
#   'layer',
#   'botrytis',
#   'dryness',
#   'elements',
#   'superb',
#   'wine'],
#  ['much', 'sum', 'parts', 'sheer', 'intensity', 'makes', 'fabulous'],
#  ['finish',
#   'prolongs',
#   'pleasure',
#   'acidity',
#   'mingling',
#   'pure',
#   'concentration',
#   'wonderful',
#   'unforgettable',
#   'honey',
#   'fresh',
#   'fruit'],
#  ['question', 'huge', 'richness', 'initial', 'aroma'],
#  ['smooth', 'totally', 'voluptuous', 'immediately', 'appealing'],
#  ['flavors',
#   'sweetest',
#   'runny',
#   'honey',
#   'matched',
#   'acidity',
#   'emphasize',
#   'ripe',
#   'peach',
#   'dried',
#   'apricot',
#   'flavors'],
#  ['hafner', 'pioneer', 'austrian', 'ice', 'wine'],
#  ['every', 'one', 'considerable', 'range', 'ice', 'wines', 'work'],
#  ['one'],
#  ['right', 'piercing', 'acidity', 'give', 'lift', 'sweetness', 'wine'],
#  ['sweet', 'pineapple', 'peach', 'flavors', 'add', 'extra', 'richness'],
#  ['rich', 'might', 'expect', 'botrytised', 'chardonnay'],
#  ['remains',
#   'surprisingly',
#   'young',
#   'sign',
#   'years',
#   'aging',
#   'acidity',
#   'coming',
#   'freshly',
#   'maple',
#   'syrup',
#   'baked',
#   'apple',
#   'flavors'],
#  ['finish', 'brings', 'acidity', 'right', 'front'],
#  ['intensely',
#   'rich',
#   'wine',
#   'balanced',
#   'delicious',
#   'refreshing',
#   'acidity'],
#  ['honey',
#   'lemon',
#   'main',
#   'thread',
#   'flavors',
#   'weaving',
#   'soft',
#   'rich',
#   'fruit'],
#  ['acidity', 'likelihood', 'wine', 'age', 'well'],
#  ['chardonnay',
#   'came',
#   'number',
#   'vintage',
#   'last',
#   'time',
#   'kracher',
#   'released',
#   'full',
#   'range',
#   'tbas',
#   'dry',
#   'botrytis'],
#  ['fascinating',
#   'see',
#   'acidity',
#   'great',
#   'sweet',
#   'present',
#   'wine',
#   'beautifully',
#   'balanced'],
#  ['vanilla',
#   'caramel',
#   'ripe',
#   'peach',
#   'flavors',
#   'beautifully',
#   'fresh',
#   'pure'],
#  ['quite',
#   'sweet',
#   'ultimately',
#   'bit',
#   'simple',
#   'partially',
#   'botrytized',
#   'chardonnay',
#   'clocks',
#   'residual',
#   'sugar'],
#  ['fleeting',
#   'whiff',
#   'volatile',
#   'acidity',
#   'might',
#   'bother',
#   'sensitive',
#   'tasters',
#   'also',
#   'plenty',
#   'ripe',
#   'pineapple',
#   'dried',
#   'apricot',
#   'flavors'],
#  ['imported', 'dc', 'imports', 'llc'],
#  ['big',
#   'step',
#   'pasler',
#   'ba',
#   'tba',
#   'boasts',
#   'rich',
#   'pear',
#   'dried',
#   'apricot',
#   'aromas',
#   'carry',
#   'hint',
#   'volatility',
#   'followed',
#   'wine',
#   'tastes',
#   'like',
#   'pear',
#   'nectar',
#   'nuances',
#   'apricot',
#   'tangerine'],
#  ['mouthwatering', 'acidity', 'keeps', 'finish', 'lively'],
#  ['nan', 'successful', 'kracher', 'two', 'chardonnays'],
#  ['hugely',
#   'rich',
#   'elegant',
#   'combining',
#   'toast',
#   'flavors',
#   'well',
#   'smooth',
#   'concentrated',
#   'fruit'],
#  ['finish',
#   'hint',
#   'orange',
#   'marmalade',
#   'fine',
#   'delicate',
#   'balancing',
#   'acidity'],
#  ['round',
#   'smooth',
#   'wine',
#   'creamy',
#   'wine',
#   'touch',
#   'toast',
#   'elegant',
#   'fruit'],
#  ['opulent', 'elegant', 'time', 'rich', 'fruit', 'flavors', 'honey', 'finish'],
#  ['second',
#   'chardonnay',
#   'kracher',
#   'tbas',
#   'may',
#   'less',
#   'successful',
#   'nummer',
#   'still',
#   'impressive',
#   'concentrated',
#   'intense',
#   'liquorous',
#   'flavors'],
#  ['layers',
#   'toast',
#   'wine',
#   'kracher',
#   'describes',
#   'new',
#   'wave',
#   'perhaps',
#   'dominant',
#   'elements',
#   'wine'],
#  ['pale',
#   'gold_color',
#   'wine',
#   'shows',
#   'great',
#   'concentrated',
#   'fruit',
#   'botrytis',
#   'dryness',
#   'flavors',
#   'toffee'],
#  ['lacking', 'acidity', 'ready_drink'],
#  ['term',
#   'traditionally',
#   'used',
#   'describe',
#   'sweet',
#   'wine',
#   'noble',
#   'rot'],
#  ['expressed', 'wine', 'style', 'fresh', 'poised'],
#  ['flavors', 'currants', 'ripe', 'quince', 'give', 'sweetness', 'acidity'],
#  ['rich', 'sweet', 'toasty', 'elements', 'spice'],
#  ['chardonnay', 'exotic', 'wine', 'cinnamon', 'flavors', 'well', 'sweetness'],
#  ['lacks', 'extra', 'edge', 'acidity', 'give', 'distinction'],
#  ['attractive',
#   'aromas',
#   'ripe',
#   'white',
#   'peaches',
#   'touch',
#   'dry',
#   'honey',
#   'make',
#   'wine',
#   'enticing'],
#  ['although',
#   'sweet',
#   'sweetness',
#   'restrained',
#   'flavors',
#   'star',
#   'fruit',
#   'high',
#   'acidity',
#   'combination',
#   'layer',
#   'dryness'],
#  ['aromas', 'vanilla', 'touch', 'tropical', 'fruits'],
#  ['palate', 'soft', 'sweet', 'vanilla'],
#  ['hints', 'acidity', 'underneath', 'faint', 'hints', 'indeed'],
#  ['golden', 'color'],
#  ['aroma', 'also', 'features', 'vanilla', 'oak', 'hint', 'butterscotch'],
#  ['terribly',
#   'sweet',
#   'bit',
#   'tweener',
#   'sweet',
#   'enough',
#   'really',
#   'dessert',
#   'wine',
#   'sweet',
#   'accompany',
#   'dinner'],
#  ['dark', 'honey', 'gold_color', 'reminiscent', 'cider'],
#  ['interesting',
#   'use',
#   'ripe',
#   'chardonnay',
#   'finishes',
#   'overly',
#   'sour',
#   'almost',
#   'bitter'],
#  ['smoky',
#   'touch',
#   'bottling',
#   'mike',
#   'sinor',
#   'buttercream',
#   'light',
#   'butterscotch',
#   'macadamia_nut',
#   'toast',
#   'nose'],
#  ['palate',
#   'also',
#   'full',
#   'nutty',
#   'toasty',
#   'notes',
#   'yet',
#   'dissected',
#   'nervy',
#   'acidity',
#   'rounded',
#   'edges',
#   'soft',
#   'butter',
#   'flavors'],
#  ['great', 'combo', 'savory', 'spice', 'acidic', 'structure'],
#  ['tangerine',
#   'citrus',
#   'aromas',
#   'give',
#   'bouquet',
#   'orangey',
#   'element',
#   'pinch',
#   'oak',
#   'tarragon',
#   'well'],
#  ['palate',
#   'mild',
#   'buttery',
#   'texture',
#   'creamy',
#   'flavors',
#   'peach',
#   'apple'],
#  ['honeyed', 'creamy', 'simple', 'finish'],
#  ['nutty',
#   'spicy',
#   'plenty',
#   'toasty',
#   'buttery',
#   'elements',
#   'chardonnay',
#   'lush',
#   'midpalate',
#   'reasonably',
#   'long',
#   'finish',
#   'citrus',
#   'wood',
#   'spice'],
#  ['drink'],
#  ['toasty',
#   'buttery',
#   'laced',
#   'tropical_fruit',
#   'chardonnay',
#   'manages',
#   'pull',
#   'grace',
#   'aplomb',
#   'thanks',
#   'healthy',
#   'acid',
#   'levels',
#   'admirable',
#   'concentration'],
#  ['long',
#   'finish',
#   'drink',
#   'stylish',
#   'deep',
#   'adelsheim',
#   'caitlin',
#   'reserve',
#   'bottling',
#   'gem'],
#  ['plump',
#   'green',
#   'yellow',
#   'fruits',
#   'buttressed',
#   'sweet',
#   'spice',
#   'toasted',
#   'hazelnut',
#   'flavors',
#   'barrel',
#   'fermentation'],
#  ['round', 'full', 'seductive', 'ca', 'wait', 'next', 'sip', 'next', 'glass'],
#  ['honeyed',
#   'peaches',
#   'nose',
#   'suggest',
#   'high',
#   'levels',
#   'ripeness',
#   'peachy',
#   'succulence',
#   'less',
#   'evident',
#   'palate',
#   'flavors',
#   'reined',
#   'submission',
#   'tart',
#   'acids'],
#  ['fullish', 'body', 'crisp', 'even', 'hard', 'finish'],
#  ['wet',
#   'difficult',
#   'vintage',
#   'much',
#   'oregon',
#   'alcohol',
#   'listed',
#   'light',
#   'green',
#   'chardonnay',
#   'suggests',
#   'simply',
#   'ripen'],
#  ['touch',
#   'minerality',
#   'tart',
#   'green_apple',
#   'flavors',
#   'thin',
#   'begin',
#   'seem',
#   'vanish'],
#  ['midpalate'],
#  ['wine',
#   'delivers',
#   'plenty',
#   'honey',
#   'peach',
#   'notes',
#   'upfront',
#   'closes',
#   'lime',
#   'mineral',
#   'notes',
#   'tiny',
#   'proportion',
#   'eden',
#   'valley',
#   'riesling',
#   'blended'],
#  ['crisp', 'steely'],
#  ['fading',
#   'fast',
#   'plump',
#   'chard',
#   'pretty',
#   'much',
#   'expected',
#   'lots',
#   'oak',
#   'covering',
#   'peach',
#   'butterscotch',
#   'apple',
#   'cider',
#   'aromas',
#   'flavors'],
#  ['borderline', 'cloying'],
#  ['sophisticated',
#   'chardonnay',
#   'balances',
#   'vibrant',
#   'fruit',
#   'flavors',
#   'light',
#   'spicy',
#   'oak'],
#  ['lime',
#   'citrus',
#   'nose',
#   'backed',
#   'flavors',
#   'rounded',
#   'fruit',
#   'toasty',
#   'wooded',
#   'character'],
#  ['understated',
#   'elegant',
#   'lingering',
#   'finish',
#   'wine',
#   'makes',
#   'impact',
#   'gets',
#   'everything',
#   'right',
#   'memorable',
#   'way'],
#  ['lower',
#   'depths',
#   'value',
#   'zone',
#   'find',
#   'respectable',
#   'chard',
#   'offers',
#   'light',
#   'melon',
#   'tropical_fruit',
#   'aromas',
#   'front',
#   'flavors'],
#  ['acidic', 'citrusy', 'style', 'wine', 'yet', 'flush', 'sour'],
#  ['frankly', 'bold', 'aromas', 'melon', 'pear', 'tinged', 'butter'],
#  ['slightly',
#   'honeyed',
#   'fruit',
#   'gradually',
#   'overtaken',
#   'spicy',
#   'peppery',
#   'elements',
#   'finish',
#   'plump',
#   'fresh',
#   'reasonably',
#   'fair',
#   'value',
#   'australian',
#   'chardonnay'],
#  ['bouquet',
#   'sports',
#   'popcorn',
#   'butter',
#   'also',
#   'zesty',
#   'tropical_fruit',
#   'apple',
#   'blossom',
#   'aromas'],
#  ['palate', 'rich', 'balanced', 'pear', 'toffee', 'flavors'],
#  ['warm', 'woody', 'throughout', 'firm', 'acidity', 'winner'],
#  ['perfumed', 'reticent', 'simple', 'apple', 'almond', 'aromas', 'flavors'],
#  ['feels',
#   'touch',
#   'flat',
#   'palate',
#   'due',
#   'modest',
#   'acidity',
#   'basic',
#   'new',
#   'world',
#   'chardonnay',
#   'good'],
#  ['drink', 'right', 'away', 'best', 'results'],
#  ['plump', 'ripe', 'certain'],
#  ['buttery',
#   'peach',
#   'aromas',
#   'call',
#   'overt',
#   'warm',
#   'honeyed',
#   'palate',
#   'punch',
#   'seems',
#   'big',
#   'side',
#   'meaning',
#   'may',
#   'hold',
#   'long'],
#  ['chard', 'easy', 'chilean', 'style'],
#  ['flat',
#   'disjointed',
#   'aggressively',
#   'oaky',
#   'flavors',
#   'cover',
#   'hints',
#   'fruit'],
#  ['undertone', 'gummy', 'plastic', 'finish'],
#  ['shows',
#   'pretty',
#   'wild',
#   'flower',
#   'aromas',
#   'well',
#   'pickle',
#   'overall',
#   'wine',
#   'distinguishes',
#   'ripe',
#   'grapefruit',
#   'flavor',
#   'touched',
#   'cucumber'],
#  ['lot', 'fruit', 'like', 'fruit', 'salad', 'mixed', 'bowl'],
#  ['imported', 'morande', 'usa'],
#  ['tropical_fruit', 'mixed', 'fairly', 'heavy', 'oak', 'theme'],
#  ['nose',
#   'offers',
#   'melon',
#   'pineapple',
#   'butter',
#   'palate',
#   'fat',
#   'creamy',
#   'plenty',
#   'vanilla'],
#  ['finishes', 'lot', 'wood', 'enough', 'acid', 'keep', 'things', 'balanced'],
#  ['imported', 'palm', 'bay', 'imports'],
#  ['light', 'front', 'canned', 'peach', 'pear', 'aromas'],
#  ['vibrant', 'clean', 'sweet', 'apricot', 'peach', 'flavors'],
#  ['good', 'enough', 'mouth', 'hint', 'banana', 'citrus', 'finish'],
#  ['oaky', 'despite', 'classification'],
#  ['imported',
#   'canandaigua',
#   'wine',
#   'chardonnay',
#   'opens',
#   'understated',
#   'scents',
#   'apples',
#   'honey',
#   'follows',
#   'earthy',
#   'minerally',
#   'flavors',
#   'fold',
#   'hints',
#   'apple',
#   'citrus',
#   'pear'],
#  ['imported', 'golden', 'kaan', 'usa'],
#  ['gold_color', 'good', 'texture'],
#  ['somewhat',
#   'short',
#   'intensity',
#   'however',
#   'ample',
#   'oak',
#   'almond',
#   'apple',
#   'pear',
#   'flavors'],
#  ['weighty', 'terribly', 'expressive'],
#  ['appropriate', 'acidity', 'good', 'salmon', 'like'],
#  ['imported',
#   'wine',
#   'agencies',
#   'consistent',
#   'vintage',
#   'vintage',
#   'three',
#   'rivers',
#   'makes',
#   'chardonnay',
#   'soft',
#   'buttery',
#   'style',
#   'showing',
#   'round',
#   'fruit',
#   'flavors',
#   'spiced',
#   'citrus',
#   'highlights'],
#  ['good', 'value'],
#  ['light',
#   'style',
#   'hints',
#   'butterscotch',
#   'clean',
#   'transparent',
#   'flavors'],
#  ['fruit', 'elegant', 'pleasant', 'seems', 'overmatched', 'alcohol'],
#  ['wine',
#   'faint',
#   'scent',
#   'clove',
#   'modest',
#   'flavors',
#   'pineapple',
#   'lemon'],
#  ['finishes', 'hint', 'anise'],
#  ['dijon', 'clones', 'willamette', 'valley', 'less', 'common', 'washington'],
#  ['taut',
#   'almost',
#   'racy',
#   'wine',
#   'packed',
#   'green',
#   'berries',
#   'citrus',
#   'flavors',
#   'nicely',
#   'finished',
#   'lightly',
#   'toasted',
#   'oak'],
#  ['severe',
#   'tart',
#   'wine',
#   'green',
#   'fruit',
#   'offset',
#   'sharp',
#   'accents',
#   'oak',
#   'vanilla'],
#  ['decanting',
#   'would',
#   'helpful',
#   'set',
#   'aside',
#   'another',
#   'years',
#   'bottle',
#   'age'],
#  ['buttery', 'lactic', 'big', 'aromas', 'baked', 'apples'],
#  ['laden',
#   'vanilla',
#   'dried',
#   'spices',
#   'turns',
#   'tangy',
#   'citrusy',
#   'finish',
#   'doubt',
#   'intended',
#   'balance',
#   'sensations',
#   'sweetness',
#   'butter'],
#  ['law', 'says', 'beaujolais', 'red', 'although', 'people', 'think'],
#  ['stellar',
#   'chardonnay',
#   'comes',
#   'limestone',
#   'soils',
#   'south',
#   'beaujolais',
#   'imported',
#   'made',
#   'entirely',
#   'stainless_steel'],
#  ['small',
#   'portion',
#   'wine',
#   'comes',
#   'parcel',
#   'really',
#   'taste',
#   'effects',
#   'much',
#   'sense',
#   'extra',
#   'weight',
#   'palate'],
#  ['pure',
#   'chardonnay',
#   'flavors',
#   'intense',
#   'concentration',
#   'crisp',
#   'acidity',
#   'long',
#   'lingering',
#   'finish'],
#  ['hawke',
#   'bay',
#   'chardonnay',
#   'shows',
#   'warmer',
#   'climate',
#   'region',
#   'ripe',
#   'plump',
#   'flavors',
#   'stone',
#   'fruits',
#   'backed',
#   'hints',
#   'honey',
#   'smoke'],
#  ['pleasingly',
#   'harmonious',
#   'rendition',
#   'chardonnay',
#   'region',
#   'known',
#   'red',
#   'wines'],
#  ['nan', 'chardonnay', 'delivers', 'bit', 'extra'],
#  ['plump', 'soft', 'fruit', 'hint', 'honey', 'plenty', 'butterscotch'],
#  ['even', 'hint', 'licorice'],
#  ['forward', 'fruity', 'effort', 'flavors'],
#  ['yellow_fruit',
#   'nuances',
#   'abound',
#   'slightly',
#   'offering',
#   'area',
#   'better',
#   'known',
#   'growing',
#   'cabernet'],
#  ['pear',
#   'pineapple',
#   'lemon',
#   'aromas',
#   'flavors',
#   'predominate',
#   'finishing',
#   'bit',
#   'heat',
#   'slightly',
#   'rough',
#   'acids'],
#  ['warm',
#   'climate',
#   'barossa',
#   'reflected',
#   'heavy',
#   'sweet',
#   'fruit',
#   'flavors'],
#  ['melon',
#   'guava',
#   'honey',
#   'aromas',
#   'flavors',
#   'lack',
#   'zip',
#   'definition',
#   'certainly',
#   'lack',
#   'ripeness'],
#  ['another', 'wine', 'portal', 'del', 'alto', 'cusp', 'drinkability'],
#  ['potent', 'butterscotch', 'cream', 'aromas', 'seem', 'authentic'],
#  ['resiny', 'flavors', 'mask', 'fruit', 'finishes', 'flat'],
#  ['taut',
#   'steely',
#   'chardonnay',
#   'muscular',
#   'firm',
#   'tastes',
#   'stone',
#   'mineral',
#   'herb',
#   'citrus'],
#  ['complex', 'appealing', 'mix', 'supported', 'vivid', 'acids'],
#  ['fine', 'length', 'precise', 'elegant', 'flavors', 'light', 'touch', 'oak'],
#  ['chardonnay'],
#  ['best', 'buy'],
#  [],
#  ['essence', 'fresh', 'crisp', 'light', 'chilean', 'chardonnay'],
#  ['light',
#   'dose',
#   'oak',
#   'supports',
#   'pear',
#   'apple',
#   'fruit',
#   'finish',
#   'smooth',
#   'nicely',
#   'nutty'],
#  ['offers',
#   'ripe',
#   'yellow',
#   'peaches',
#   'golden',
#   'package',
#   'virtually',
#   'guaranteed',
#   'offend'],
#  ['good', 'versatile', 'quaffer'],
#  ['particularly', 'fresh', 'wine', 'crisp', 'chardonnay', 'region'],
#  ['light',
#   'poised',
#   'packed',
#   'fresh',
#   'apple',
#   'flavors',
#   'tang',
#   'lemon_zest',
#   'end'],
#  ['drink'],
#  ['gorgeous', 'sparkler', 'finesse', 'fragrance'],
#  ['opens',
#   'enticing',
#   'scents',
#   'alpine',
#   'wildflower',
#   'pear',
#   'flint',
#   'whiff',
#   'pastry'],
#  ['savory',
#   'elegant',
#   'palate',
#   'airy',
#   'weightless',
#   'character',
#   'doling',
#   'ripe',
#   'apple',
#   'creamy',
#   'white_peach',
#   'minerals',
#   'dollop',
#   'vanilla',
#   'dry',
#   'juicy',
#   'finish'],
#  ['silky', 'perlage', 'gives', 'polished', 'irresistible', 'texture'],
#  ['enticing',
#   'scents',
#   'ripe',
#   'pear',
#   'citrus',
#   'zest',
#   'pastry',
#   'alpine',
#   'herb',
#   'mingle',
#   'together',
#   'elegant',
#   'refreshing',
#   'sparkler'],
#  ['bright',
#   'silky',
#   'palate',
#   'refined',
#   'perlage',
#   'tangy',
#   'acidity',
#   'offset',
#   'lemon',
#   'golden_delicious',
#   'apple',
#   'ginger',
#   'mineral',
#   'note',
#   'evoking',
#   'wet_stone'],
#  ['packed',
#   'festive',
#   'bottle',
#   'honor',
#   'firm',
#   'anniversary',
#   'chardonnay',
#   'opens',
#   'delicate',
#   'scents',
#   'white',
#   'stone_fruit',
#   'bread_crust',
#   'hint',
#   'toast'],
#  ['elegant',
#   'palate',
#   'offers',
#   'yellow',
#   'apple',
#   'pear',
#   'citrus',
#   'zest',
#   'hazelnut',
#   'alongside',
#   'fresh',
#   'acidity',
#   'refined',
#   'perlage'],
#  ['yellow',
#   'wildflower',
#   'orchard_fruit',
#   'aromas',
#   'mingle',
#   'whiff',
#   'baked',
#   'bread'],
#  ['creamy',
#   'palate',
#   'bright',
#   'acidity',
#   'lifts',
#   'flavors',
#   'golden_delicious',
#   'tangy',
#   'lemon',
#   'hint',
#   'hazelnut'],
#  ['silky', 'mousse', 'lends', 'finesse'],
#  ['orchard_fruit',
#   'citrusy',
#   'aromas',
#   'mingle',
#   'glass',
#   'together',
#   'yeasty',
#   'whiff',
#   'bread_dough'],
#  ['palate',
#   'bright',
#   'acidity',
#   'lifts',
#   'white_peach',
#   'ripe',
#   'apple',
#   'toasted',
#   'almond',
#   'note',
#   'alongside',
#   'soft',
#   'persistent',
#   'mousse'],
#  ['chamomile',
#   'bread_crust',
#   'vanilla',
#   'white',
#   'pear',
#   'aromas',
#   'shape',
#   'bouquet'],
#  ['vibrant',
#   'linear',
#   'delivering',
#   'yellow',
#   'apple',
#   'meyer_lemon',
#   'white',
#   'almond',
#   'alongside',
#   'bright',
#   'acidity',
#   'silky',
#   'mousse',
#   'softens',
#   'crisp',
#   'dry',
#   'finish'],
#  ['made',
#   'entirely_chardonnay',
#   'opens',
#   'aromas',
#   'ripe',
#   'yellow',
#   'apple',
#   'chamomile',
#   'flower',
#   'bread_crust',
#   'whiff',
#   'toast'],
#  ['elegant',
#   'palate',
#   'continuous',
#   'perlage',
#   'underscores',
#   'candied',
#   'citrus',
#   'zest',
#   'ripe',
#   'white',
#   'toasted',
#   'hazelnut'],
#  ['fresh', 'acidity', 'brightens', 'rich', 'flavors'],
#  ['textured', 'wine', 'cool', 'character', 'plenty', 'minerality'],
#  ['apple', 'fruits', 'cut', 'lemon', 'acidity', 'give', 'freshness'],
#  ['time', 'softer', 'side', 'comes', 'balanced', 'dosage'],
#  ['drink'],
#  ['aromas',
#   'toasted',
#   'hazelnut',
#   'coffee',
#   'bread_crust',
#   'mingle',
#   'together'],
#  ['aromas',
#   'carry',
#   'mature',
#   'linear',
#   'palate',
#   'join',
#   'ripe',
#   'yellow',
#   'apple',
#   'hint',
#   'citrus',
#   'rind'],
#  ['elegant',
#   'perlage',
#   'lends',
#   'finesse',
#   'fresh',
#   'acidity',
#   'lifts',
#   'close'],
#  ['toast', 'walnut', 'bread_crust', 'aromas', 'lead', 'nose'],
#  ['aromas',
#   'carry',
#   'firm',
#   'lean',
#   'palate',
#   'along',
#   'mature',
#   'golden_delicious',
#   'apple',
#   'medicinal',
#   'herb',
#   'hint',
#   'hazelnut'],
#  ['crisp', 'acidity', 'vivacious', 'perlage', 'provide', 'backdrop'],
#  ['made',
#   'entirely_chardonnay',
#   'vivacious',
#   'sparkler',
#   'aromas',
#   'bread_crust',
#   'orchard_fruit',
#   'whiff',
#   'citrus'],
#  ['reflecting',
#   'nose',
#   'vibrant',
#   'palate',
#   'delivers',
#   'toasted',
#   'hazelnut',
#   'ripe',
#   'yellow',
#   'apple',
#   'lemon_zest',
#   'set',
#   'bright',
#   'acidity',
#   'continuous',
#   'perlage'],
#  ['baked',
#   'bread',
#   'ripe',
#   'orchard_fruit',
#   'pressed',
#   'chamomile',
#   'aromas',
#   'lead',
#   'way',
#   'vibrant',
#   'palate',
#   'shows',
#   'mature',
#   'golden_delicious',
#   'apple',
#   'pear',
#   'candied',
#   'citrus'],
#  ['continuous', 'perlage', 'provides', 'backdrop'],
#  ['aromas',
#   'dried',
#   'field',
#   'flowers',
#   'bread_crust',
#   'white',
#   'orchard_fruit',
#   'appear',
#   'bright',
#   'linear',
#   'sparkler',
#   'made',
#   'entirely_chardonnay'],
#  ['vibrant',
#   'palate',
#   'offers',
#   'golden_delicious',
#   'apple',
#   'lemon_zest',
#   'toasted',
#   'hazelnut',
#   'alongside',
#   'lively',
#   'bubbles'],
#  ['field', 'flower', 'yellow', 'stone_fruit', 'aromas', 'lead', 'way'],
#  ['reflecting',
#   'nose',
#   'vibrant',
#   'palate',
#   'evokes',
#   'golden',
#   'apple',
#   'citrus',
#   'drop',
#   'hint',
#   'toasted',
#   'hazelnut',
#   'alongside',
#   'bright',
#   'acidity',
#   'lively',
#   'perlage'],
#  ['white_flower',
#   'white',
#   'stone_fruit',
#   'citrus',
#   'bread_dough',
#   'aromas',
#   'come_together',
#   'lively',
#   'sparkler'],
#  ['vibrant',
#   'palate',
#   'vigorous',
#   'perlage',
#   'bright',
#   'acidity',
#   'accompany',
#   'yellow',
#   'apple',
#   'lemon_zest',
#   'tangy',
#   'hint',
#   'minerals'],
#  ['toasted', 'bread', 'chamomile', 'flower', 'whiff', 'nut', 'lead', 'way'],
#  ['mirroring',
#   'nose',
#   'linear',
#   'almost',
#   'lean',
#   'palate',
#   'evokes',
#   'mature',
#   'yellow',
#   'apple',
#   'citrus',
#   'zest',
#   'hint',
#   'toasted',
#   'hazelnut'],
#  ['crisp', 'fresh', 'bright', 'acidity', 'lively', 'bubbles'],
#  ['white',
#   'orchard_fruit',
#   'yellow',
#   'spring_flower',
#   'crusty',
#   'bread',
#   'aromas',
#   'lead',
#   'way',
#   'soft',
#   'sparkler',
#   'made',
#   'chardonnay'],
#  ['bright',
#   'palate',
#   'offers',
#   'golden_delicious',
#   'apple',
#   'candied',
#   'lemon',
#   'slice',
#   'toasted',
#   'nut',
#   'set',
#   'crisp',
#   'acidity',
#   'refined',
#   'perlage'],
#  ['alpine',
#   'herb',
#   'white',
#   'stone_fruit',
#   'aromas',
#   'mingle',
#   'whiff',
#   'bread_crust'],
#  ['racy',
#   'palate',
#   'offers',
#   'lemon',
#   'golden_delicious',
#   'apple',
#   'hint',
#   'nut',
#   'alongside',
#   'lively',
#   'perlage'],
#  ['dusty',
#   'dry',
#   'apple',
#   'pear',
#   'aromas',
#   'come',
#   'whiff',
#   'talcum',
#   'powder'],
#  ['chardonnay', 'feels', 'plump', 'soft', 'moderate', 'low', 'acidity'],
#  ['apple',
#   'vanilla',
#   'spiced',
#   'pear',
#   'flavors',
#   'steady',
#   'finish',
#   'regular',
#   'special'],
#  ['made',
#   'entirely_chardonnay',
#   'lively',
#   'sparkler',
#   'aromas',
#   'white',
#   'spring_flower',
#   'white',
#   'stone_fruit',
#   'whiff',
#   'bread_dough'],
#  ['palate',
#   'offers',
#   'yellow',
#   'apple',
#   'orange_peel',
#   'toasted',
#   'hazelnut',
#   'alongside',
#   'vivacious',
#   'perlage'],
#  ['warm', 'rich', 'wine'],
#  ['ripe',
#   'fruits',
#   'soft',
#   'acidity',
#   'come_together',
#   'well',
#   'bonus',
#   'touch',
#   'yeastiness'],
#  ['drink', 'fruity', 'wine'],
#  ['made',
#   'charmat',
#   'method',
#   'aromas',
#   'dried',
#   'tropical_fruit',
#   'citrus',
#   'leesy',
#   'whiff',
#   'bread_dough',
#   'carry',
#   'fresh',
#   'palate',
#   'along',
#   'mature',
#   'yellow',
#   'apple',
#   'lemon',
#   'drop'],
#  ['silky', 'mousse', 'softens', 'hazelnut', 'finish'],
#  ['refreshing',
#   'enjoyable',
#   'lively',
#   'sparkler',
#   'aromas',
#   'white',
#   'spring_flower',
#   'ripe',
#   'orchard_fruit',
#   'whiff',
#   'bread_dough'],
#  ['breezy',
#   'palate',
#   'offers',
#   'juicy',
#   'golden',
#   'apple',
#   'candied',
#   'lemon',
#   'slice',
#   'closing',
#   'bitter',
#   'almond',
#   'note'],
#  ['opens',
#   'subtle',
#   'aromas',
#   'spring_flower',
#   'medicinal',
#   'herb',
#   'white',
#   'stone_fruit',
#   'whiff',
#   'bread_crust'],
#  ['brisk',
#   'palate',
#   'reflects',
#   'nose',
#   'offering',
#   'yellow',
#   'apple',
#   'lemon',
#   'thyme',
#   'toasted',
#   'note',
#   'alongside',
#   'brisk',
#   'acidity',
#   'lively',
#   'perlage'],
#  ['may', 'added', 'dosage', 'wine', 'ripe', 'warm', 'fruits', 'need'],
#  ['texture',
#   'soft',
#   'open',
#   'full',
#   'white',
#   'fruits',
#   'attractive',
#   'acidity'],
#  ['drink', 'wine'],
#  ['legendary',
#   'champagne',
#   'produced',
#   'exceptional',
#   'years',
#   'comes',
#   'village',
#   'le',
#   'mesnil',
#   'des',
#   'blancs'],
#  ['made', 'chardonnay', 'aged', 'many', 'years', 'release'],
#  ['minerality',
#   'concentration',
#   'beautiful',
#   'fruit',
#   'still',
#   'astonishingly',
#   'young',
#   'deserve',
#   'aging'],
#  ['drink',
#   'produced',
#   'small',
#   'walled',
#   'vineyard',
#   'close',
#   'lanson',
#   'winery',
#   'reims',
#   'splendid',
#   'wine'],
#  ['richness',
#   'balanced',
#   'intense',
#   'freshness',
#   'minerality',
#   'chardonnay',
#   'apple',
#   'citrus',
#   'flavors',
#   'still',
#   'background'],
#  ['mature', 'wine', 'ready_drink'],
#  ['grapes',
#   'coming',
#   'chardonnay',
#   'heartland',
#   'des',
#   'blancs',
#   'wine',
#   'epitome',
#   'structured',
#   'textured',
#   'fruit',
#   'essential',
#   'addition',
#   'age'],
#  ['still',
#   'hinting',
#   'freshness',
#   'still',
#   'textured',
#   'wine',
#   'also',
#   'rich',
#   'flavors',
#   'cut',
#   'limes'],
#  ['drink',
#   'beautifully',
#   'mature',
#   'rich',
#   'wine',
#   'shines',
#   'minerality',
#   'texture',
#   'chardonnay',
#   'des',
#   'blancs'],
#  ['intensity',
#   'concentration',
#   'make',
#   'ripe',
#   'toasty',
#   'wine',
#   'crisp',
#   'deliciously',
#   'balance'],
#  ['drink'],
#  ['wine', 'made', 'chardonnay', 'des', 'blancs'],
#  ['palate',
#   'textured',
#   'mineral',
#   'driven',
#   'crisp',
#   'flavor',
#   'comes',
#   'together',
#   'well'],
#  ['enjoyed',
#   'although',
#   'better',
#   'vintage',
#   'blanc_de',
#   'blancs',
#   'completes',
#   'full',
#   'range',
#   'produced',
#   'rothschild',
#   'properties',
#   'bordeaux'],
#  ['full', 'minerality', 'well', 'crisp', 'intensity'],
#  ['fruit', 'almost', 'mature', 'still', 'fresh', 'tangy'],
#  ['textured',
#   'champagne',
#   'best',
#   'explosive',
#   'ripe',
#   'wine',
#   'part',
#   'trilogy',
#   'producer',
#   'made',
#   'three',
#   'greatest',
#   'villages',
#   'champagne'],
#  ['tense', 'wine', 'rich', 'white', 'fruits'],
#  ['still_young',
#   'wait',
#   'wine',
#   'comes',
#   'small',
#   'chardonnay',
#   'vineyard',
#   'des',
#   'blancs'],
#  ['shows',
#   'beauty',
#   'mature',
#   'chardonnay',
#   'minerality',
#   'totally',
#   'subsumed',
#   'richness',
#   'elegance',
#   'texture'],
#  ['ready_drink'],
#  ['wine',
#   'comes',
#   'le',
#   'mesnil',
#   'one',
#   'top',
#   'villages',
#   'des',
#   'blancs',
#   'produced',
#   'grand_cru',
#   'vineyards'],
#  ['textured', 'mineral', 'young', 'wine', 'like'],
#  ['white',
#   'fruit',
#   'shows',
#   'concentrated',
#   'texture',
#   'become',
#   'dominant',
#   'wine',
#   'matures'],
#  ['drink',
#   'ripe',
#   'opulent',
#   'wine',
#   'rich',
#   'white',
#   'fruits',
#   'warm',
#   'rounded',
#   'texture'],
#  ['much',
#   'rich',
#   'ruinart',
#   'style',
#   'made',
#   'extra',
#   'special',
#   'maturity',
#   'wine'],
#  ['still', 'mineral_texture', 'wine', 'fruit', 'become', 'toasty', 'rich'],
#  ['drink'],
#  ['one',
#   'pair',
#   'wines',
#   'producer',
#   'ages',
#   'significant',
#   'amount',
#   'reserve',
#   'wine',
#   'bottle',
#   'blending'],
#  ['result',
#   'concentrated',
#   'wine',
#   'superrich',
#   'never',
#   'losing',
#   'sight',
#   'strong',
#   'minerality',
#   'comes',
#   'top',
#   'chardonnay',
#   'des',
#   'blancs'],
#  ['drink',
#   'bottling',
#   'produced',
#   'fruit',
#   'grown',
#   'des',
#   'blancs',
#   'heart',
#   'chardonnay',
#   'champagne',
#   'wine',
#   'richly',
#   'mineral',
#   'deliciously',
#   'fruity'],
#  ['dry', 'tense', 'vintage', 'wine', 'aged'],
#  ['drink',
#   'wine',
#   'one',
#   'trilogy',
#   'individual',
#   'village',
#   'wines',
#   'des',
#   'blancs'],
#  ['moving', 'youth', 'growing', 'hinting', 'toastiness', 'come'],
#  ['however', 'kept', 'intense', 'minerality', 'chalk_soil', 'des', 'blancs'],
#  ['drink',
#   'structured',
#   'wine',
#   'drawing',
#   'fruit',
#   'des',
#   'blancs',
#   'wine',
#   'concentrated',
#   'still_young'],
#  ['density', 'comes', 'strong', 'minerality', 'balanced', 'lemon', 'flavor'],
#  ['textured', 'taut', 'wine', 'needs', 'time', 'cellar'],
#  ['drink',
#   'champagne',
#   'made',
#   'old',
#   'vines',
#   'giving',
#   'concentration',
#   'also',
#   'oak',
#   'aging',
#   'adding',
#   'toasty',
#   'character'],
#  ['rich', 'well', 'balanced', 'mature'],
#  ['drink'],
#  ['producer',
#   'wines',
#   'labeled',
#   'extra',
#   'brut',
#   'therefore',
#   'drier',
#   'brut'],
#  ['bottling',
#   'intense',
#   'minerality',
#   'bursting',
#   'tight',
#   'texture',
#   'crisp',
#   'white',
#   'fruits'],
#  ['still_young', 'fresh', 'wine', 'age', 'little'],
#  ['drink',
#   'producer',
#   'located',
#   'mailly',
#   'north',
#   'slopes',
#   'montagne_de',
#   'reims'],
#  ['wine', 'everything', 'style', 'crisp', 'tight', 'mineral', 'driven'],
#  ['apple', 'fresh', 'citrus', 'come', 'strongly', 'even', 'years'],
#  ['wine', 'ready_drink'],
#  ['mainly',
#   'chardonnay',
#   'des',
#   'blancs',
#   'wine',
#   'good',
#   'balance',
#   'maturing',
#   'rich',
#   'apple',
#   'fruits',
#   'mineral_texture'],
#  ['notes',
#   'spice',
#   'yeastiness',
#   'coming',
#   'give',
#   'wine',
#   'generous',
#   'aftertaste'],
#  ['drink'],
#  ['pure', 'chardonnay', 'des', 'blancs', 'makes', 'intense', 'wine'],
#  ['tight',
#   'texture',
#   'mineral_character',
#   'shot',
#   'white',
#   'fruits',
#   'topped',
#   'citrus'],
#  ['wine', 'elegant', 'ready_drink'],
#  ['fruit', 'selected', 'vineyards', 'went', 'ripe', 'wine'],
#  ['smoothly',
#   'textured',
#   'hints',
#   'minerality',
#   'much',
#   'ripe',
#   'white',
#   'fruits',
#   'touches',
#   'toastiness'],
#  ['could',
#   'time',
#   'drink',
#   'vines',
#   'top',
#   'des',
#   'blancs',
#   'vineyards',
#   'cramant',
#   'chouilly',
#   'wine',
#   'rich',
#   'strongly_mineral'],
#  ['swathes',
#   'apple',
#   'citrus',
#   'fruits',
#   'wrapped',
#   'crisply',
#   'textured',
#   'wine'],
#  ['drink', 'bottling'],
#  ['slopes', 'montagne_de', 'reims', 'provide', 'fruit', 'wine'],
#  ['much',
#   'reserve',
#   'wine',
#   'blend',
#   'given',
#   'richness',
#   'sense',
#   'poised',
#   'maturity'],
#  ['also',
#   'fills',
#   'mineral_texture',
#   'emphasizing',
#   'ripe',
#   'white',
#   'fruits',
#   'full',
#   'aftertaste'],
#  ['drink', 'wine'],
#  ['based',
#   'le',
#   'heart',
#   'des',
#   'blancs',
#   'producer',
#   'knows',
#   'thing',
#   'two',
#   'chardonnay',
#   'champagnes'],
#  ['proof', 'intense', 'mineral', 'wine'],
#  ['depth', 'flavor', 'giving', 'concentration', 'well', 'richness'],
#  ['drink',
#   'bottling',
#   'smooth',
#   'ripe',
#   'wine',
#   'creamy',
#   'mousse',
#   'hints',
#   'mature',
#   'rich',
#   'fruit'],
#  ['well',
#   'poised',
#   'hinting',
#   'minerality',
#   'also',
#   'boasting',
#   'great',
#   'fruitiness'],
#  ['drink',
#   'northern',
#   'slopes',
#   'montagne_de',
#   'reims',
#   'vines',
#   'wine',
#   'classified',
#   'grand_cru'],
#  ['produced',
#   'refined',
#   'stylish',
#   'wine',
#   'tense',
#   'minerality',
#   'intense',
#   'acidity'],
#  ['bottling',
#   'layers',
#   'citrus',
#   'crisp',
#   'texture',
#   'still_young',
#   'better',
#   'one',
#   'pair',
#   'champagnes',
#   'vineyards'],
#  ['made',
#   'chardonnay',
#   'minerality',
#   'main',
#   'thrust',
#   'richness',
#   'balanced',
#   'intense',
#   'acidity',
#   'beautiful',
#   'white',
#   'stone',
#   'fruits'],
#  ['quite',
#   'ready_drink',
#   'wait',
#   'mineral',
#   'textured',
#   'rich',
#   'full',
#   'flavors',
#   'wine',
#   'taut',
#   'nervy',
#   'intense',
#   'acidity',
#   'balanced',
#   'ripeness'],
#  ['bottling', 'tight', 'texture', 'needs', 'age'],
#  ['drink',
#   'crisp',
#   'textured',
#   'wine',
#   'still',
#   'offers',
#   'great',
#   'freshness'],
#  ['acidity',
#   'taut',
#   'white',
#   'fruits',
#   'zesty',
#   'hinting',
#   'toastiness',
#   'fine',
#   'texture'],
#  ['elegant', 'wine', 'ready_drink'],
#  ['name', 'indicates', 'wine'],
#  ['richness',
#   'counterbalances',
#   'dryness',
#   'delivering',
#   'ripe',
#   'white',
#   'fruits',
#   'intense',
#   'citrus',
#   'well',
#   'intensely',
#   'mineral_texture'],
#  ['drink', 'bottling'],
#  ['blend',
#   'grand_cru',
#   'fruit',
#   'wine',
#   'rich',
#   'also',
#   'tense',
#   'mineral',
#   'aging',
#   'potential'],
#  ['citrus',
#   'acidity',
#   'allied',
#   'crisp',
#   'apples',
#   'produce',
#   'fruity',
#   'side',
#   'well',
#   'balanced',
#   'wine'],
#  ['better',
#   'stylish',
#   'wine',
#   'balances',
#   'crisp',
#   'fruit',
#   'mineral_texture',
#   'acidity'],
#  ['wine', 'still_young', 'tight', 'zesty', 'texture', 'crispness'],
#  ['better',
#   'blend',
#   'chardonnay',
#   'montagne_de',
#   'reims',
#   'des',
#   'blancs',
#   'still_young',
#   'soft',
#   'fruitiness',
#   'contrasts',
#   'mineral_texture'],
#  ['acidity', 'cushioned', 'relatively', 'high', 'dosage'],
#  ['drink', 'perfumed', 'wine'],
#  ['wine',
#   'crisp',
#   'mineral',
#   'driven',
#   'yet',
#   'balanced',
#   'softer',
#   'texture',
#   'develop',
#   'wine',
#   'matures'],
#  ['attractive',
#   'fruitiness',
#   'contrasts',
#   'bright',
#   'acidity',
#   'tangy',
#   'aftertaste'],
#  ['pure',
#   'chardonnay',
#   'gives',
#   'tight',
#   'edge',
#   'otherwise',
#   'warm',
#   'rich',
#   'fruitiness',
#   'wine'],
#  ['acidity',
#   'integrates',
#   'ripe',
#   'yellow',
#   'fruits',
#   'give',
#   'rich',
#   'champagne',
#   'ready_drink'],
#  ['luminescence',
#   'moon',
#   'reflected',
#   'baron',
#   'family',
#   'crisp',
#   'chardonnay'],
#  ['taut', 'dry', 'wine', 'attractive', 'apple', 'tight', 'citrus', 'flavors'],
#  ['acidity',
#   'lively',
#   'bright',
#   'texture',
#   'come_together',
#   'give',
#   'perfumed',
#   'wine',
#   'touched',
#   'minerality',
#   'ready_drink'],
#  ['textured',
#   'wine',
#   'properly',
#   'mineral',
#   'taut',
#   'structure',
#   'crisp',
#   'also',
#   'riper',
#   'background'],
#  ['dosage',
#   'sufficient',
#   'give',
#   'soft',
#   'edge',
#   'contrast',
#   'mineral_texture'],
#  ['drink', 'wine'],
#  ['crisp', 'wine', 'taut', 'tightly', 'textured'],
#  ['flavors', 'green_plum', 'apple', 'come', 'making', 'balanced', 'wine'],
#  ['bottling', 'ready_drink'],
#  ['spring_flower', 'aromas', 'attractive', 'minerality', 'hallmarks', 'wine'],
#  ['bright',
#   'apple',
#   'ripe',
#   'apricot',
#   'flavors',
#   'partner',
#   'attractive',
#   'acidity'],
#  ['everything',
#   'bound',
#   'together',
#   'smooth',
#   'aftertaste',
#   'suggesting',
#   'relatively',
#   'high',
#   'dosage'],
#  ['drink'],
#  ['poised',
#   'wine',
#   'offers',
#   'touches',
#   'toast',
#   'well',
#   'crisp',
#   'tight',
#   'fruit'],
#  ['follows',
#   'house',
#   'style',
#   'high',
#   'dosage',
#   'brut',
#   'balances',
#   'attractive',
#   'minerality',
#   'brisk',
#   'aftertaste'],
#  ['drink'],
#  ['crisper',
#   'laurent',
#   'wines',
#   'textured',
#   'mineral',
#   'chardonnay',
#   'full',
#   'acidity',
#   'citrus',
#   'fruits',
#   'poised',
#   'character'],
#  ['fresh', 'aftertaste', 'enhances', 'fruitiness'],
#  ['drink'],
#  ['softer',
#   'texture',
#   'many',
#   'pure',
#   'chardonnay',
#   'champagnes',
#   'still',
#   'offers',
#   'plenty',
#   'acidity',
#   'minerality'],
#  ['delicate',
#   'apple',
#   'citrus',
#   'fruits',
#   'balance',
#   'acidity',
#   'warm',
#   'aftertaste'],
#  ['drink'],
#  ['made',
#   'chardonnay',
#   'aube',
#   'offers',
#   'ripe',
#   'fruits',
#   'apples',
#   'crisp',
#   'pears',
#   'dominant'],
#  ['warm',
#   'fruity',
#   'champagne',
#   'lightly',
#   'textured',
#   'rich',
#   'mineral_edge',
#   'end'],
#  ['drink'],
#  ['blend',
#   'premier',
#   'grand_cru',
#   'vineyards',
#   'wine',
#   'finely',
#   'textured',
#   'attractive',
#   'apple',
#   'flavors',
#   'line',
#   'minerality'],
#  ['plenty', 'fruitiness', 'although', 'aftertaste', 'dry'],
#  ['drink'],
#  ['situated', 'des', 'blancs', 'cooperative', 'specializes', 'champagnes'],
#  ['wine', 'main', 'soft', 'creamy', 'fruity'],
#  ['touches',
#   'minerality',
#   'show',
#   'lightly',
#   'crisp',
#   'fruitiness',
#   'dry',
#   'aftertaste'],
#  ['drink'],
#  ['fresh',
#   'clear',
#   'pure',
#   'notes',
#   'green',
#   'red_apple',
#   'merest',
#   'hint',
#   'lemon',
#   'creating',
#   'appetizing',
#   'nose'],
#  ['palate',
#   'restrained',
#   'clear',
#   'fruit',
#   'fine',
#   'creamy',
#   'bubbles',
#   'lend',
#   'freshness',
#   'disperse',
#   'lovely',
#   'creamy',
#   'apple',
#   'aromas'],
#  ['elegant', 'sparkler', 'dry', 'classy', 'finish'],
#  ['lovely', 'depth', 'shows', 'umami', 'finish'],
#  ['ripe', 'yellow', 'apple', 'vanilla', 'dominate', 'nose'],
#  ['richness',
#   'continues',
#   'palate',
#   'full',
#   'flavor',
#   'gently',
#   'fizzing',
#   'bubbles'],
#  ['rich', 'rounded', 'yet', 'dry', 'fresh', 'wine'],
#  ['consider', 'food', 'rather', 'aperitif'],
#  ['lovely', 'sure', 'evolve'],
#  ['drink'],
#  ['gentle',
#   'notes',
#   'golden_delicious',
#   'apple',
#   'nose',
#   'continue',
#   'equal',
#   'mellowness',
#   'palate'],
#  ['hints',
#   'grapefruit',
#   'add',
#   'note',
#   'bitter',
#   'pith',
#   'frothy',
#   'bubbles',
#   'liven',
#   'things'],
#  ['dry', 'finish', 'zesty', 'generously', 'fruity', 'fresh'],
#  ['nose', 'shy', 'earthy', 'edge'],
#  ['flavors',
#   'palate',
#   'gently',
#   'fruited',
#   'suggest',
#   'faint',
#   'lemon',
#   'yellow',
#   'apple'],
#  ['mousse', 'lively', 'fresh', 'overall', 'remains', 'little', 'subdued'],
#  ['finish', 'clean', 'dry', 'fresh'],
#  ['aromas', 'white', 'flowers', 'yeast', 'game', 'carry', 'nose'],
#  ['overly', 'foamy', 'shape', 'palate'],
#  ['phenolic', 'flavors', 'grassy', 'finish', 'oily', 'bitter'],
#  ['chardonnay', 'smell', 'taste', 'like'],
#  ['crisp',
#   'elegant',
#   'sophisticated',
#   'wine',
#   'enticing',
#   'mineral',
#   'aromas',
#   'tiny',
#   'bubbles',
#   'form',
#   'soothing',
#   'mousse',
#   'lemon',
#   'mineral',
#   'ginger',
#   'flavors'],
#  ['tastes', 'steely', 'first', 'sip', 'slowly', 'opens', 'richness', 'depth'],
#  ['best',
#   'part',
#   'range',
#   'wines',
#   'given',
#   'low',
#   'dosage',
#   'make',
#   'extra',
#   'dry',
#   'wine',
#   'blend',
#   'chardonnay',
#   'des',
#   'blancs',
#   'marne',
#   'valley'],
#  ['strongly_mineral',
#   'texture',
#   'tight',
#   'acidity',
#   'well',
#   'intense',
#   'grapefruit',
#   'flavors'],
#  ['needs',
#   'age',
#   'extra',
#   'months',
#   'keep',
#   'bottling',
#   'tight',
#   'minerality',
#   'goes',
#   'crisp',
#   'apple',
#   'freshness',
#   'textured',
#   'perfumed',
#   'wine'],
#  ['layers', 'acidity', 'great', 'fruit', 'firm', 'structure', 'finish'],
#  ['drink'],
#  ['tightly',
#   'mineral',
#   'almost',
#   'severely',
#   'textured',
#   'young',
#   'wine',
#   'needs',
#   'open'],
#  ['crisp',
#   'apples',
#   'go',
#   'intense',
#   'acidity',
#   'mitigated',
#   'softness',
#   'dosage'],
#  ['wine', 'already', 'balanced', 'open', 'deliciously'],
#  ['drink',
#   'although',
#   'labeled',
#   'effectively',
#   'blanc_de',
#   'blancs',
#   'chardonnay',
#   'grown',
#   'marne',
#   'valley'],
#  ['crisp',
#   'deliciously',
#   'refreshing',
#   'bright',
#   'acidity',
#   'citrus',
#   'fruits'],
#  ['lightly', 'textured', 'certainly', 'tangy', 'wine', 'ready_drink'],
#  ['made',
#   'entirely_chardonnay',
#   'multiple',
#   'vintages',
#   'gorgeous',
#   'chiseled',
#   'sparkler',
#   'offers',
#   'citrus',
#   'zest',
#   'pineapple',
#   'pastry',
#   'dough',
#   'alpine',
#   'herb',
#   'aromas'],
#  ['vibrant',
#   'pristine',
#   'palate',
#   'boasts',
#   'pure',
#   'fruit',
#   'mineral',
#   'sensations',
#   'doling',
#   'crisp',
#   'yellow',
#   'apple',
#   'juicy',
#   'nectarine',
#   'vanilla',
#   'flint',
#   'notes'],
#  ['bright',
#   'acidity',
#   'elegant',
#   'perlage',
#   'give',
#   'remarkable',
#   'freshness',
#   'finesse'],
#  ['well',
#   'balanced',
#   'dry',
#   'somewhat',
#   'restrained',
#   'fruit',
#   'flavors',
#   'classic',
#   'style',
#   'brut',
#   'please',
#   'lot',
#   'different',
#   'palates'],
#  ['tiny',
#   'bubbles',
#   'persist',
#   'glass',
#   'elegant',
#   'crisp',
#   'mouthfeel',
#   'clean',
#   'fresh',
#   'finish'],
#  ['rounded',
#   'yeasty',
#   'aromas',
#   'baking',
#   'bread',
#   'sharp',
#   'apple',
#   'skins',
#   'slightest',
#   'hint',
#   'petrol',
#   'show',
#   'nose',
#   'bubbly',
#   'dave',
#   'potter'],
#  ['bubbles',
#   'incredibly',
#   'sharp',
#   'tangy',
#   'citrus',
#   'flavors',
#   'refreshingly',
#   'sour',
#   'dried',
#   'apple',
#   'touch',
#   'rounding',
#   'midpalate'],
#  ['cloudy',
#   'glass',
#   'strong',
#   'excited',
#   'bubbles',
#   'game',
#   'pet',
#   'nat',
#   'shows',
#   'lots',
#   'aromas',
#   'pink_lady',
#   'pippin',
#   'well',
#   'white',
#   'rose',
#   'petals',
#   'anjou_pear',
#   'slightest',
#   'hint',
#   'yeasty',
#   'funk'],
#  ['also',
#   'clean',
#   'crisp',
#   'tight',
#   'palate',
#   'bosc_pear',
#   'grapefruit_pith',
#   'citrus',
#   'skin',
#   'tang',
#   'finish'],
#  ['enticing',
#   'scents',
#   'white',
#   'spring',
# ...
#   'nose'],
#  ['ripe',
#   'round',
#   'palate',
#   'delivers',
#   'golden_delicious',
#   'apple',
#   'hazelnut',
#   'hint',
#   'bread_crust',
#   'alongside',
#   'soft',
#   'perlage'],
#  ['made',
#   'entirely_chardonnay',
#   'offers',
#   'delicate',
#   'scents',
#   'ripe',
#   'orchard_fruit',
#   'toasted',
#   'bread'],
#  ['rich',
#   'smooth',
#   'palate',
#   'presents',
#   'mature',
#   'yellow',
#   'apple',
#   'toasted',
#   'hazelnut',
#   'candied',
#   'nectarine',
#   'zest',
#   'alongside',
#   'creamy',
#   'perlage'],
#  ['notes', 'vanilla', 'lemon', 'drop', 'wrap', 'finish'],
#  ['based',
#   'des',
#   'blancs',
#   'nicolas',
#   'feuillatte',
#   'access',
#   'fine',
#   'chardonnay',
#   'wine'],
#  ['lightly',
#   'perfumed',
#   'white',
#   'flowers',
#   'crisp',
#   'fresh',
#   'sliced',
#   'apple',
#   'lemon',
#   'right',
#   'front'],
#  ['wine', 'fruity', 'age', 'well'],
#  ['either',
#   'drink',
#   'wait',
#   'maturity',
#   'producer',
#   'based',
#   'small',
#   'de',
#   'produced',
#   'bright',
#   'zesty',
#   'crisp',
#   'style',
#   'blanc_de',
#   'blancs'],
#  ['emphasizes',
#   'fruitiness',
#   'lively',
#   'light',
#   'touch',
#   'chalky',
#   'minerality'],
#  ['full', 'ripe', 'fruity', 'ready_drink'],
#  ['restrained',
#   'lemon',
#   'freshness',
#   'mixed',
#   'yeast',
#   'stone',
#   'constitutes',
#   'inviting',
#   'nose'],
#  ['palate',
#   'fresh',
#   'taut',
#   'creamy',
#   'lemon',
#   'brioche',
#   'breadiness',
#   'yeast'],
#  ['light',
#   'bodied',
#   'fresh',
#   'fine',
#   'fizzing',
#   'bubbles',
#   'dry',
#   'elegant',
#   'finish',
#   'reminiscent',
#   'golden_delicious',
#   'apples'],
#  ['wine', 'young', 'full', 'initial', 'burst', 'crisp', 'fruit'],
#  ['apple',
#   'citrus',
#   'flavors',
#   'mineral_texture',
#   'still',
#   'developing',
#   'filling',
#   'taut',
#   'character',
#   'acidity'],
#  ['ready_drink',
#   'bread_crust',
#   'toast',
#   'citrus',
#   'zest',
#   'aromas',
#   'lead',
#   'nose',
#   'creamy',
#   'sparkler'],
#  ['soft',
#   'frothy',
#   'palate',
#   'presents',
#   'ripe',
#   'apple',
#   'white_peach',
#   'toasted',
#   'hazelnut'],
#  ['small', 'persistent', 'bubbles', 'lift', 'finish'],
#  ['pretty',
#   'sparkler',
#   'opens',
#   'lovely',
#   'scents',
#   'white',
#   'spring_flower',
#   'summer',
#   'orchard_fruit',
#   'whiff',
#   'candied',
#   'citrus',
#   'zest'],
#  ['soft',
#   'creamy',
#   'palate',
#   'offers',
#   'mature',
#   'yellow',
#   'apple',
#   'nectarine',
#   'light',
#   'pastry',
#   'note',
#   'alongside',
#   'small',
#   'persistent',
#   'beads'],
#  ['finishes', 'nutty', 'note'],
#  ['blossom',
#   'fruit',
#   'offered',
#   'nose',
#   'dewy',
#   'scent',
#   'ripe',
#   'yellow',
#   'mirabelles',
#   'captivating'],
#  ['primary',
#   'notes',
#   'play',
#   'fizzy',
#   'frothy',
#   'palate',
#   'boosted',
#   'generous',
#   'dosage'],
#  ['easy', 'fresh', 'lively', 'exuberant'],
#  ['yeasty', 'autolytic', 'notes', 'still', 'background'],
#  ['change', 'little', 'bottle', 'age'],
#  ['opens', 'aromas', 'suggesting', 'toasted', 'nut', 'oak', 'bread_crust'],
#  ['soft',
#   'palate',
#   'offers',
#   'mature',
#   'yellow',
#   'apple',
#   'skin',
#   'toast',
#   'citrus',
#   'zest',
#   'confectionary',
#   'note',
#   'alongside',
#   'creamy',
#   'perlage'],
#  ['bitter', 'almond', 'marks', 'finish'],
#  ['made',
#   'entirely_chardonnay',
#   'lightly',
#   'scented',
#   'whiffs',
#   'citrus',
#   'yeasty',
#   'hint',
#   'bread_dough'],
#  ['bright',
#   'soft',
#   'palate',
#   'offers',
#   'yellow',
#   'apple',
#   'lemon_zest',
#   'bitter',
#   'almond',
#   'alongside',
#   'firm',
#   'acidity'],
#  ['delicate',
#   'aromas',
#   'chamomile',
#   'flower',
#   'toast',
#   'thyme',
#   'orchard_fruit',
#   'lead',
#   'nose'],
#  ['vibrant',
#   'palate',
#   'offers',
#   'yellow',
#   'apple',
#   'tangerine',
#   'zest',
#   'bread_crust',
#   'alongside',
#   'vigorous',
#   'persistent',
#   'bubbles'],
#  ['made',
#   'chardonnay',
#   'straightforward',
#   'sparkler',
#   'opens',
#   'aromas',
#   'suggesting',
#   'ripe',
#   'orchard_fruit',
#   'dried',
#   'chamomile',
#   'flower',
#   'whiff',
#   'hazelnut'],
#  ['bracing',
#   'palate',
#   'offers',
#   'golden_delicious',
#   'apple',
#   'toasted',
#   'nut',
#   'alongside',
#   'brisk',
#   'perlage'],
#  ['aromas',
#   'toast',
#   'vanilla',
#   'apple',
#   'bread_crust',
#   'follow',
#   'invigorating',
#   'palate',
#   'along',
#   'candied',
#   'citrus',
#   'walnut'],
#  ['small', 'vigorous', 'bubbles', 'give', 'vibrant', 'edge'],
#  ['aromas',
#   'bread_crust',
#   'pastry',
#   'cream',
#   'toast',
#   'come_together',
#   'glass'],
#  ['creamy',
#   'palate',
#   'offers',
#   'mature',
#   'pear',
#   'yellow',
#   'apple',
#   'toasted',
#   'hazelnut',
#   'alongside',
#   'soft',
#   'mousse'],
#  ['toast',
#   'bread_crust',
#   'citrus',
#   'aromas',
#   'carry',
#   'firm',
#   'lively',
#   'palate',
#   'together',
#   'candied',
#   'lemon',
#   'drop'],
#  ['brisk', 'acidity', 'sharp', 'bubbles', 'provide', 'edgy', 'framework'],
#  ['subdued',
#   'aromas',
#   'pear',
#   'toast',
#   'yeasty',
#   'note',
#   'bread_dough',
#   'lead',
#   'nose'],
#  ['bracing',
#   'palate',
#   'offers',
#   'golden_delicious',
#   'apple',
#   'lime',
#   'toasted',
#   'walnut',
#   'alongside',
#   'sharp',
#   'acidity'],
#  ['finishes', 'somewhat', 'bitter', 'note'],
#  ['aromas',
#   'bread_crust',
#   'dried',
#   'chamomile',
#   'mature',
#   'orchard_fruit',
#   'come_together'],
#  ['palate',
#   'offers',
#   'ripe',
#   'skin',
#   'vanilla',
#   'toasted',
#   'oak',
#   'alongside',
#   'vigorous',
#   'perlage'],
#  ['somewhat', 'brief', 'finish', 'closes', 'note', 'bitter', 'almond'],
#  ['aromas',
#   'yellow',
#   'apple',
#   'toast',
#   'walnut',
#   'lead',
#   'nose',
#   'carry',
#   'simple',
#   'palate',
#   'along',
#   'notes',
#   'dried',
#   'bread',
#   'crumbs'],
#  ['vigorous', 'bubbles', 'provide', 'somewhat', 'abrasive', 'texture'],
#  ['creaminess', 'stone', 'signalled', 'nose'],
#  ['palate',
#   'opens',
#   'generous',
#   'spirit',
#   'unites',
#   'green_apple',
#   'crispness',
#   'lemon',
#   'freshness',
#   'shortbread',
#   'richness',
#   'chalky',
#   'depth'],
#  ['undertow', 'lemon', 'oil', 'lasting', 'length'],
#  ['something', 'generous', 'rounded', 'wine', 'stem', 'dosage'],
#  ['intriguing', 'wonderfully', 'dry', 'totally', 'lasting'],
#  ['still', 'taut', 'gain', 'bottle', 'age'],
#  ['lively',
#   'crisp',
#   'apple',
#   'notes',
#   'nose',
#   'immediately',
#   'signal',
#   'freshness'],
#  ['palate',
#   'follows',
#   'equally',
#   'brisk',
#   'green_apple',
#   'citrus',
#   'notes',
#   'mellowed',
#   'fittingly',
#   'fine',
#   'soft',
#   'creamy',
#   'mousse'],
#  ['lithe', 'great', 'purity'],
#  ['conjures',
#   'visions',
#   'clear',
#   'brooks',
#   'green',
#   'meadows',
#   'budding',
#   'elderflower'],
#  ['crisp',
#   'notes',
#   'echo',
#   'long',
#   'make',
#   'totally',
#   'refreshing',
#   'brisk',
#   'finish'],
#  ['scented', 'freshness', 'lemon', 'apple', 'hits', 'nose'],
#  ['palate',
#   'follows',
#   'frothy',
#   'lively',
#   'mousse',
#   'majors',
#   'crisp',
#   'lemon',
#   'flavors'],
#  ['tart', 'bracing', 'refreshing', 'totally', 'joyful'],
#  ['leaves',
#   'palate',
#   'tingling',
#   'english',
#   'verve',
#   'also',
#   'hints',
#   'hedonism',
#   'underneath',
#   'stony',
#   'depths',
#   'finishes',
#   'brisk',
#   'flourish'],
#  ['delicious',
#   'flavors',
#   'like',
#   'pear',
#   'tart',
#   'soft',
#   'expansive',
#   'mousse',
#   'make',
#   'wine',
#   'easy',
#   'love'],
#  ['combines',
#   'richness',
#   'luxurious',
#   'texture',
#   'light',
#   'flavors',
#   'butter',
#   'vanilla',
#   'pear',
#   'nutmeg'],
#  ['honeycomb',
#   'fruit',
#   'basket',
#   'melon',
#   'berry',
#   'ride',
#   'wave',
#   'medium',
#   'acidity',
#   'mellowed',
#   'sweetness',
#   'touch',
#   'green_apple'],
#  ['good', 'call', 'morning', 'mimosas'],
#  ['wine',
#   'shows',
#   'maturity',
#   'toast',
#   'flavors',
#   'coming',
#   'creamy',
#   'mousse'],
#  ['white',
#   'stone_fruit',
#   'streaks',
#   'citrus',
#   'give',
#   'fresher',
#   'end',
#   'wine'],
#  ['ripe', 'apples', 'creamed', 'pear', 'give', 'wine', 'fruity', 'character'],
#  ['balanced', 'crisp', 'acidity', 'touches', 'almond', 'lime', 'juice'],
#  ['wine', 'immediately_attractive', 'ready_drink'],
#  ['winemaker', 'johan', 'malan'],
#  ['mature',
#   'beauty',
#   'still',
#   'plenty',
#   'life',
#   'left',
#   'vibrant',
#   'notes',
#   'orange_peel',
#   'apple',
#   'skin',
#   'peach',
#   'met',
#   'complementary',
#   'tones',
#   'honeycomb',
#   'candied',
#   'ginger',
#   'toasted',
#   'challah'],
#  ['palate',
#   'full',
#   'creamy',
#   'bright',
#   'mouthwatering',
#   'acidity',
#   'cuts',
#   'rich',
#   'baked',
#   'apple',
#   'pear',
#   'butter',
#   'toasted',
#   'sweet',
#   'spice',
#   'flavors'],
#  ['drink'],
#  ['slightly',
#   'briny',
#   'pear',
#   'apple',
#   'aromas',
#   'lead',
#   'stony',
#   'citric',
#   'palate',
#   'firmness'],
#  ['flavors',
#   'lime',
#   'wet',
#   'stones',
#   'exact',
#   'limited',
#   'finishes',
#   'fresh',
#   'tight',
#   'mildly',
#   'salty',
#   'flavor'],
#  ['consistently',
#   'one',
#   'best',
#   'sparkling',
#   'pointe',
#   'many',
#   'excellent',
#   'offerings',
#   'elegant',
#   'wine',
#   'shows',
#   'classic',
#   'expressions',
#   'apple',
#   'lemon',
#   'juxtaposed',
#   'complex',
#   'notes',
#   'brioche',
#   'nuts',
#   'cream'],
#  ['acidity',
#   'fine',
#   'delicate',
#   'mousse',
#   'fill',
#   'palate',
#   'intensity',
#   'harmony'],
#  ['finish', 'lingers', 'exceptionally', 'long'],
#  ['aged', 'year', 'lees', 'wine', 'rich', 'tangy', 'refreshingly', 'crisp'],
#  ['blanc_de',
#   'blancs',
#   'strongly_mineral',
#   'character',
#   'adds',
#   'tight',
#   'character',
#   'texture'],
#  ['age',
#   'months',
#   'bottle',
#   'drink_late',
#   'winemakers',
#   'mikey',
#   'giugni',
#   'michael',
#   'brughelli',
#   'first',
#   'admit',
#   'odd',
#   'style',
#   'wine',
#   'people',
#   'digging',
#   'style'],
#  ['aromas',
#   'sour',
#   'apple',
#   'grass',
#   'passion',
#   'fruit',
#   'arise',
#   'palate',
#   'tight',
#   'bubbles',
#   'unleash',
#   'exotic',
#   'tropical',
#   'fruits',
#   'like',
#   'green',
#   'papaya',
#   'green',
#   'banana'],
#  ['tight',
#   'fresh',
#   'aromas',
#   'asian_pear',
#   'honeysuckle',
#   'key_lime',
#   'pie',
#   'converge',
#   'sparkler',
#   'new',
#   'estate',
#   'temecula'],
#  ['palate',
#   'shows',
#   'sliced',
#   'apples',
#   'yellow',
#   'pears',
#   'ripe',
#   'nectarine',
#   'rounder',
#   'white_peach',
#   'even',
#   'creamy',
#   'cherimoya',
#   'flavors'],
#  ['though',
#   'region',
#   'known',
#   'sparklers',
#   'seem',
#   'regular',
#   'bubbles',
#   'well'],
#  ['made',
#   'chardonnay',
#   'des',
#   'blancs',
#   'intensely',
#   'crisp',
#   'fresh',
#   'wine',
#   'maturing',
#   'well',
#   'although',
#   'nowhere',
#   'near',
#   'ready_drink'],
#  ['fine',
#   'wine',
#   'tight',
#   'steely',
#   'mineral_character',
#   'citrus',
#   'acidity',
#   'balanced',
#   'warmer',
#   'apricot',
#   'crisp',
#   'apples'],
#  ['drink',
#   'special',
#   'club',
#   'group',
#   'growers',
#   'rate',
#   'taste',
#   'wines',
#   'release'],
#  ['produced',
#   'grand_cru',
#   'vineyards',
#   'oger',
#   'intensely',
#   'fresh',
#   'crisp',
#   'wine'],
#  ['brightest', 'lime', 'juice', 'acidity', 'cool', 'perfumed', 'bright'],
#  ['lively', 'bottling', 'could', 'months', 'bottle'],
#  ['creamy', 'texture', 'ripe', 'apple', 'fruits', 'rich', 'rounded', 'style'],
#  ['certainly',
#   'fresh',
#   'also',
#   'yellow',
#   'white',
#   'stone_fruit',
#   'flavors',
#   'cut',
#   'acidity',
#   'citrus'],
#  ['coming',
#   'southern',
#   'de',
#   'bar',
#   'open',
#   'fruity',
#   'champagne',
#   'still',
#   'plenty',
#   'proper',
#   'steely',
#   'aftertaste'],
#  ['nine', 'years', 'wine', 'ready_drink'],
#  ['produced',
#   'chardonnay',
#   'grown',
#   'montagne_de',
#   'reims',
#   'region',
#   'south',
#   'fresh',
#   'wine',
#   'fruity',
#   'mineral',
#   'although',
#   'definite',
#   'tilt',
#   'towards',
#   'citrus',
#   'acidity',
#   'perfumed',
#   'acidity'],
#  ['delicate', 'stylish', 'bottling', 'ready_drink'],
#  ['palmer', 'brand', 'name', 'grouping', 'seven', 'growers'],
#  ['sparkler',
#   'rich',
#   'toasty',
#   'seductive',
#   'notes',
#   'toasted',
#   'brioche',
#   'cashew',
#   'apple',
#   'skin',
#   'drizzled',
#   'touch',
#   'buttery',
#   'caramel',
#   'sauce'],
#  ['decadence',
#   'continues',
#   'palate',
#   'rich',
#   'flavors',
#   'dried',
#   'apple',
#   'orange',
#   'oil',
#   'listed',
#   'medium',
#   'acidity',
#   'lively',
#   'carbonation'],
#  ['well', 'balanced', 'drinkable'],
#  ['blanc_de',
#   'blancs',
#   'made',
#   'stony',
#   'hill',
#   'chardonnay',
#   'clone',
#   'planted',
#   'single',
#   'block',
#   'producer',
#   'since',
#   'planted',
#   'pinot_noir'],
#  ['sparkler', 'sublime', 'mousse', 'silky', 'speckled', 'minerality'],
#  ['lemon',
#   'pear',
#   'brine',
#   'combine',
#   'good',
#   'effect',
#   'palate',
#   'buoying',
#   'exuberant',
#   'fragrances',
#   'orange_peel',
#   'cream',
#   'pie'],
#  ['delicate',
#   'dainty',
#   'mousse',
#   'bottlings',
#   'frank',
#   'blanc_de',
#   'blancs',
#   'calibrates',
#   'gossamer',
#   'layers',
#   'pristine',
#   'apple',
#   'pear',
#   'citrus',
#   'flavors',
#   'acidity'],
#  ['breathlessly',
#   'vivacious',
#   'penetrates',
#   'long',
#   'touch',
#   'sugar',
#   'cookie',
#   'crumbles'],
#  ['beautiful',
#   'wine',
#   'fresh',
#   'acidity',
#   'crisp',
#   'fruits',
#   'zesty',
#   'mineral_texture'],
#  ['apples',
#   'citrus',
#   'hints',
#   'apricots',
#   'along',
#   'intense',
#   'tangy',
#   'character',
#   'bursts',
#   'mouth'],
#  ['still_young', 'needs', 'age', 'drink', 'earliest'],
#  ['special', 'club', 'group', 'growers', 'rate', 'taste', 'wines', 'release'],
#  ['serious', 'wine', 'mineral_texture', 'tangy', 'structure'],
#  ['plenty', 'apple', 'zingy', 'orange', 'flavors'],
#  ['main', 'thrust', 'stage', 'wine', 'poised', 'considerable', 'aging'],
#  ['fresh', 'still', 'tight', 'needs', 'several', 'years'],
#  ['drink',
#   'made',
#   'grand_cru',
#   'vineyards',
#   'des',
#   'blancs',
#   'beautiful',
#   'wine',
#   'maturing',
#   'well'],
#  ['ripe',
#   'creamy',
#   'pineapple',
#   'spice',
#   'character',
#   'softened',
#   'natural',
#   'minerality',
#   'texture'],
#  ['full',
#   'mouth',
#   'ripe',
#   'rounded',
#   'wine',
#   'age',
#   'drink',
#   'better',
#   'keep',
#   'blending',
#   'recent',
#   'good',
#   'vintages',
#   'champagne',
#   'delicious',
#   'fruit',
#   'stage'],
#  ['crisp', 'bright', 'fruitiness'],
#  ['develops',
#   'mineral_texture',
#   'come',
#   'giving',
#   'richer',
#   'impressive',
#   'wine',
#   'retains',
#   'zesty',
#   'character'],
#  ['ideally', 'wait', 'months', 'purchase', 'drinking'],
#  ['heart', 'gimonnet', 'vineyards', 'des', 'blancs'],
#  ['crisp', 'chardonnay', 'intense', 'acidity', 'tight', 'texture'],
#  ['like',
#   'many',
#   'wines',
#   'dry',
#   'needs',
#   'age',
#   'allow',
#   'almost',
#   'shocking',
#   'freshness',
#   'soften'],
#  ['always', 'wine', 'food'],
#  ['drink',
#   'wine',
#   'although',
#   'age',
#   'shock',
#   'acidity',
#   'rounded',
#   'hint',
#   'toast'],
#  ['linear', 'fresh', 'intensely', 'crisp', 'citrus', 'almond', 'tones'],
#  ['drink', 'wine', 'good', 'vintage'],
#  ['based',
#   'premier_cru',
#   'chardonnay',
#   'vineyards',
#   'cuis',
#   'soft',
#   'fresh',
#   'wine',
#   'beautifully',
#   'balanced'],
#  ['apple',
#   'freshness',
#   'tangy',
#   'texture',
#   'minerality',
#   'bright',
#   'fruity',
#   'aftertaste'],
#  ['ripe', 'chardonnay', 'soft', 'texture', 'lightest', 'minerality'],
#  ['fresh', 'tangy', 'flavors', 'refreshing', 'acidity'],
#  ['aftertaste', 'burst', 'crispness', 'particularly', 'attractive'],
#  ['fresh',
#   'fruity',
#   'wine',
#   'comes',
#   'grand_cru',
#   'vineyards',
#   'oger',
#   'des',
#   'blancs'],
#  ['soft',
#   'texture',
#   'ripe',
#   'character',
#   'attractive',
#   'wine',
#   'bright',
#   'citrus',
#   'pear',
#   'flavors'],
#  ['mineral', 'streak', 'though', 'seems', 'missing'],
#  ['citron',
#   'lemon_rind',
#   'pastry',
#   'crust',
#   'aromas',
#   'travel',
#   'vigorous',
#   'palate',
#   'foaming',
#   'bubbles',
#   'racing',
#   'acidity'],
#  ['sweet', 'plastic', 'note', 'meets', 'squeeze_lemon', 'finish'],
#  ['flat', 'disparate', 'aromas', 'bread', 'white', 'fruits', 'mild'],
#  ['palate', 'plump', 'lacks', 'edge', 'structure'],
#  ['briny',
#   'flavors',
#   'tropical',
#   'fruits',
#   'finish',
#   'foamy',
#   'pickled',
#   'flavor'],
#  ['initially',
#   'restrained',
#   'nose',
#   'unfolds',
#   'slowly',
#   'shades',
#   'ripe',
#   'apple',
#   'dried',
#   'apricot',
#   'honey'],
#  ['honeyed',
#   'notes',
#   'become',
#   'effusive',
#   'air',
#   'edging',
#   'towards',
#   'honeycomb',
#   'butter',
#   'shortbread'],
#  ['despite',
#   'richness',
#   'also',
#   'illuminates',
#   'palate',
#   'body',
#   'vintage',
#   'lees',
#   'magnum',
#   'remains',
#   'slender',
#   'chalky',
#   'totally',
#   'pure'],
#  ['varietal',
#   'wine',
#   'made',
#   'oldest',
#   'chardonnay',
#   'vines',
#   'alsace',
#   'planted',
#   'purity',
#   'fruit',
#   'speaks',
#   'much',
#   'soil',
#   'united',
#   'long',
#   'flavor',
#   'fusion',
#   'development',
#   'lees',
#   'ageing'],
#  ...]

# %%
def extract_term_frequeuncies_from_bigrams(wine_bigrams):
    wine_bigrams_list = [term for sentence in wine_bigrams for term in sentence]
    wine_terms_count = {term: 0 for term in wine_bigrams_list}

    for term in wine_bigrams_list:
        if term in wine_terms_count:
            wine_terms_count[term] += 1

    wine_terms_sorted = sorted(wine_terms_count.items(), key=lambda x: x[1], reverse=True)

    return wine_terms_sorted


term_frequencies = extract_term_frequeuncies_from_bigrams(wine_bigrams)

# %%
term_frequencies

# %%
print(f'In total found from 15 to 100: {len([elem for elem in term_frequencies if elem[1] > 15 and elem[1] < 100])} ingredients')
print(f'In total found from 100 to 300: {len([elem for elem in term_frequencies if elem[1] > 99 and elem[1] < 300])} ingredients')
print(f'In total found from 300 to 600: {len([elem for elem in term_frequencies if elem[1] > 299 and elem[1] < 600])} ingredients')

# %%
print(f'In total found from 15 to 100: {[elem for elem in term_frequencies if elem[1] > 15 and elem[1] < 100]} ingredients')

# %%
def normalize_wine_reviews(reviews):
    normalized_instructions = []
    instruction_normalizer = RecipeNormalizer()
    for instructions in tqdm(reviews, total=len(reviews)):
        if instructions is np.nan:
            normalized_instructions.append(None)
            continue

        if type(instructions) == str:
            instruction_text = [instructions.lower()]
        else:
            instruction_text = [step.strip() for step in eval(instructions)]
        
            
        normalized_instructions.append(
            instruction_normalizer.normalize_instruction(
                instruction_text,
            )
        )
    return normalized_instructions

# %%
reviews = wine_dataframe.Description.to_numpy()[:500]
clean_reviews = normalize_wine_reviews(reviews)

# %%
clean_reviews[::100]
