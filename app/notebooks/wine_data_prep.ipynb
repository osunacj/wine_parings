# %%
import os
import pandas as pd
import numpy as np
import spacy


from matplotlib import pyplot as plt
from tqdm import tqdm
from helpers.prep.normalization import RecipeNormalizer
from gensim.models.phrases import Phrases, Phraser
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import nltk
import string


# nltk.download('stopwords')

BASE_PATH = "../data/wine_extracts"

# %%
# def merge_all_wine_files():
#     i = 0
#     wine_dataframe = pd.DataFrame()
#     for file in os.listdir(BASE_PATH):
#         file_location = BASE_PATH + "/" + str(file)
#         if i == 0:
#             wine_dataframe = pd.read_csv(file_location)
#             i += 1
#         else:
#             df_to_append = pd.read_csv(
#                 file_location, low_memory=False, encoding="latin-1"
#             )
#             wine_dataframe = pd.concat([wine_dataframe, df_to_append], axis=0)

#     wine_dataframe.drop_duplicates(subset=["Name"], inplace=True)

#     geographies = ["Subregion", "Region", "Province", "Country"]

#     for geo in geographies:
#         wine_dataframe[geo] = wine_dataframe[geo].apply(lambda x: str(x).strip())

#     return wine_dataframe

# %%
# wine_dataframe = merge_all_wine_files()

# %%
# wine_dataframe.to_csv('../data/produce/wine_data.csv', index=False)

wine_dataframe = pd.read_csv('../data/produce/wine_data.csv')

# %%
wine_dataframe.head(3)

# %%
wine_dataframe.columns

# %%
wine_dataframe.iloc[2]

# %%
def tokenize_corpus(all_wine_corpus):
    wine_sentences_tokenized = sent_tokenize(all_wine_corpus)
    stop_words = set(stopwords.words("english"))
    term_normalizer = RecipeNormalizer()

    all_corpus_by_word = []
    for sentence in wine_sentences_tokenized:
        sent = []
        for word in word_tokenize(sentence):
            if word not in stop_words and word.isalpha():
                sent.append(word)
        all_corpus_by_word.append(sent)

    words_in_corpus = [word for sentence in all_corpus_by_word for word in sentence]
    terms = term_normalizer.normalize_ingredients(words_in_corpus)

    previous_idx = 0
    normalized_corpus_by_words = []
    for sentence in all_corpus_by_word:
        length = len(sentence)
        new_index = previous_idx + length
        normalized_corpus_by_words.append(terms[previous_idx:new_index])
        previous_idx = new_index

    return normalized_corpus_by_words

# %%
all_wine_corpus = ' '.join(str(sentence).lower() for sentence in wine_dataframe.Description.to_numpy()[:5000])
wine_sentences_tokenized = sent_tokenize(all_wine_corpus)
stop_words = set(stopwords.words('english')) 
term_normalizer = RecipeNormalizer()

all_corpus_by_word = []
for sentence in wine_sentences_tokenized:
    sent = []
    for word in word_tokenize(sentence):
        if word not in stop_words and word.isalpha():
            sent.append(word)
    all_corpus_by_word.append(sent)

words_in_corpus = [word for sentence in all_corpus_by_word for word in sentence]
terms = term_normalizer.normalize_ingredients(
    words_in_corpus
)

# %%
previous_idx = 0
normalized_corpus_by_words = []
for sentence in all_corpus_by_word:
    length = len(sentence)
    new_index = previous_idx + length
    normalized_corpus_by_words.append(terms[previous_idx:new_index])
    previous_idx = new_index

# %%
assert len(normalized_corpus_by_words) == len(all_corpus_by_word)

# %%
wine_bigram_model = Phrases(normalized_corpus_by_words, min_count=10)
wine_bigrams = [wine_bigram_model[line] for line in all_corpus_by_word]

# %%
wine_bigrams

# %%
def extract_term_frequeuncies_from_bigrams(wine_bigrams):
    wine_bigrams_list = [term for sentence in wine_bigrams for term in sentence]
    wine_terms_count = {term: 0 for term in wine_bigrams_list}

    for term in wine_bigrams_list:
        if term in wine_terms_count:
            wine_terms_count[term] += 1

    wine_terms_sorted = sorted(wine_terms_count.items(), key=lambda x: x[1], reverse=True)

    return wine_terms_sorted


term_frequencies = extract_term_frequeuncies_from_bigrams(wine_bigrams)

# %%
term_frequencies

# %%
print(f'In total found from 15 to 100: {len([elem for elem in term_frequencies if elem[1] > 15 and elem[1] < 100])} ingredients')
print(f'In total found from 100 to 300: {len([elem for elem in term_frequencies if elem[1] > 99 and elem[1] < 300])} ingredients')
print(f'In total found from 300 to 600: {len([elem for elem in term_frequencies if elem[1] > 299 and elem[1] < 600])} ingredients')

# %%
print(f'In total found from 15 to 100: {[elem for elem in term_frequencies if elem[1] > 15 and elem[1] < 100]} ingredients')

# %%
def normalize_wine_reviews(reviews):
    normalized_instructions = []
    instruction_normalizer = RecipeNormalizer()
    for instructions in tqdm(reviews, total=len(reviews)):
        if instructions is np.nan:
            normalized_instructions.append(None)
            continue

        if type(instructions) == str:
            instruction_text = [instructions.lower()]
        else:
            instruction_text = [step.strip() for step in eval(instructions)]
        
            
        normalized_instructions.append(
            instruction_normalizer.normalize_instruction(
                instruction_text,
            )
        )
    return normalized_instructions

# %%
reviews = wine_dataframe.Description.to_numpy()[:500]
clean_reviews = normalize_wine_reviews(reviews)

# %%
clean_reviews[::100]

# %%
wine_descriptors_df = pd.read_csv('../data/wine_extracts/descriptor_mapping.csv')
wine_descriptors_df.drop(['level_2', 'level_1', 'type'], axis=1, inplace=True)

# %%
raw_descriptor = wine_descriptors_df['raw descriptor'].to_numpy()
level_3 = wine_descriptors_df.level_3.to_numpy()

descriptors = {}
for key, value in zip(raw_descriptor, level_3):
    descriptors.update({value.replace('_', ' '): value.replace('_', ' ')})

# %%
descriptors
# Out:
# {'abrasive': 'abrasive',
#  'acacia': 'acacia',
#  'acid driven': 'acid driven',
#  'aggressive': 'aggressive',
#  'airy': 'airy',
#  'allspice': 'allspice',
#  'almond': 'almond',
#  'alpine herbs': 'alpine herbs',
#  'american oak': 'american oak',
#  'angular': 'angular',
#  'anise': 'anise',
#  'apple': 'apple',
#  'apple blossom': 'apple blossom',
#  'apple pie': 'apple pie',
#  'apple sauce': 'apple sauce',
#  'apricot': 'apricot',
#  'ash': 'ash',
#  'asian spice': 'asian spice',
#  'asparagus': 'asparagus',
#  'asphalt': 'asphalt',
#  'assertive': 'assertive',
#  'astringent': 'astringent',
#  'austere': 'austere',
#  'bacon': 'bacon',
#  'baked': 'baked',
#  'baked apple': 'baked apple',
#  'baked bread': 'baked bread',
#  'baking spices': 'baking spices',
#  'balsamic': 'balsamic',
#  'banana': 'banana',
#  'band-aid': 'band-aid',
#  'barbecue': 'barbecue',
#  'bark': 'bark',
#  'barnyard': 'barnyard',
#  'basil': 'basil',
#  'bay leaf': 'bay leaf',
#  'beef': 'beef',
#  'beef jerky': 'beef jerky',
#  'beefy': 'beefy',
#  'beeswax': 'beeswax',
#  'beet': 'beet',
#  'beetroot': 'beetroot',
#  'bell pepper': 'bell pepper',
#  'bergamot': 'bergamot',
#  'berry': 'berry',
#  'big-boned': 'big-boned',
#  'bite': 'bite',
#  'bitter': 'bitter',
#  'bitter almond': 'bitter almond',
#  'bittersweet': 'bittersweet',
#  'black cherry': 'black cherry',
#  'black currant': 'black currant',
#  'black fruit': 'black fruit',
#  'black pepper': 'black pepper',
#  'black tea': 'black tea',
#  'blackberry': 'blackberry',
#  'blackberry jam': 'blackberry jam',
#  'blackberry-cassis': 'blackberry-cassis',
#  'blackcurrant': 'blackcurrant',
#  'bland': 'bland',
#  'blood orange': 'blood orange',
#  'blossom': 'blossom',
#  'blue': 'blue',
#  'blue black': 'blue black',
#  'blue flower': 'blue flower',
#  'blue fruit': 'blue fruit',
#  'blueberry': 'blueberry',
#  'blueberry pie': 'blueberry pie',
#  'bold': 'bold',
#  'bone dry': 'bone dry',
#  'botrytis': 'botrytis',
#  'boysenberry': 'boysenberry',
#  'bramble': 'bramble',
#  'brawny': 'brawny',
#  'bread': 'bread',
#  'bread crust': 'bread crust',
#  'brick': 'brick',
#  'bright': 'bright',
#  'brilliant': 'brilliant',
#  'brine': 'brine',
#  'brioche': 'brioche',
#  'brisk': 'brisk',
#  'brown': 'brown',
#  'brown butter': 'brown butter',
#  'brown spice': 'brown spice',
#  'brown sugar': 'brown sugar',
#  'bubble gum': 'bubble gum',
#  'bubblegum': 'bubblegum',
#  'bulky': 'bulky',
#  'bullish': 'bullish',
#  'buoyant': 'buoyant',
#  'burnt': 'burnt',
#  'burnt toast': 'burnt toast',
#  'butter': 'butter',
#  'butter nut': 'butter nut',
#  'butter popcorn': 'butter popcorn',
#  'buttercream': 'buttercream',
#  'butterscotch': 'butterscotch',
#  'buttery toast': 'buttery toast',
#  'cake': 'cake',
#  'cake spice': 'cake spice',
#  'campfire': 'campfire',
#  'camphor': 'camphor',
#  'candle wax': 'candle wax',
#  'candy': 'candy',
#  'caramel': 'caramel',
#  'cardamom': 'cardamom',
#  'carob': 'carob',
#  'cashew': 'cashew',
#  'cassis': 'cassis',
#  'cataloupe': 'cataloupe',
#  'cedar': 'cedar',
#  'celery': 'celery',
#  'cement': 'cement',
#  'chalk': 'chalk',
#  'chamomile': 'chamomile',
#  'charcoal': 'charcoal',
#  'charred wood': 'charred wood',
#  'cheese': 'cheese',
#  'chemical': 'chemical',
#  'cherry': 'cherry',
#  'cherry liqueur': 'cherry liqueur',
#  'cherry pie': 'cherry pie',
#  'chewi': 'chewi',
#  'chocolate': 'chocolate',
#  'choppy': 'choppy',
#  'chunky': 'chunky',
#  'cider': 'cider',
#  'cigar': 'cigar',
#  'cigar box': 'cigar box',
#  'cinnamon': 'cinnamon',
#  'citrus': 'citrus',
#  'citrus acid': 'citrus acid',
#  'citrus peel': 'citrus peel',
#  'citrus pith': 'citrus pith',
#  'clampy': 'clampy',
#  'classy': 'classy',
#  'clay': 'clay',
#  'clean': 'clean',
#  'closed': 'closed',
#  'close-grained tannin': 'close-grained tannin',
#  'clove': 'clove',
#  'clove cinnamon': 'clove cinnamon',
#  'cloying': 'cloying',
#  'coarse': 'coarse',
#  'cocoa': 'cocoa',
#  'coconut': 'coconut',
#  'coffee': 'coffee',
#  'cola': 'cola',
#  'complex': 'complex',
#  'complicated': 'complicated',
#  'compost': 'compost',
#  'compote': 'compote',
#  'concentrated': 'concentrated',
#  'concrete': 'concrete',
#  'cooked': 'cooked',
#  'cooked spice': 'cooked spice',
#  'cookie': 'cookie',
#  'corn': 'corn',
#  'cotton candy': 'cotton candy',
#  'cracker': 'cracker',
#  'cranberry': 'cranberry',
#  'cranberry pomegranate': 'cranberry pomegranate',
#  'cream': 'cream',
#  'creamy': 'creamy',
#  'crème brulee': 'crème brulee',
#  'crisp': 'crisp',
#  'crunchy': 'crunchy',
#  'cucumber': 'cucumber',
#  'cured meat': 'cured meat',
#  'currant': 'currant',
#  'custard': 'custard',
#  'cut grass': 'cut grass',
#  'dainty': 'dainty',
#  'dark': 'dark',
#  'dark berry': 'dark berry',
#  'dark chocolate': 'dark chocolate',
#  'dark fruit': 'dark fruit',
#  'deep color': 'deep color',
#  'dense': 'dense',
#  'depth': 'depth',
#  'diesel': 'diesel',
#  'dill': 'dill',
#  'diluted': 'diluted',
#  'dr pepper': 'dr pepper',
#  'dried herb': 'dried herb',
#  'dry': 'dry',
#  'dull': 'dull',
#  'dust': 'dust',
#  'earth': 'earth',
#  'earthy': 'earthy',
#  'easy': 'easy',
#  'edgy': 'edgy',
#  'effervescent': 'effervescent',
#  'elderberry': 'elderberry',
#  'elderflower': 'elderflower',
#  'elegant': 'elegant',
#  'espresso': 'espresso',
#  'eucalyptus': 'eucalyptus',
#  'expansive': 'expansive',
#  'extracted': 'extracted',
#  'exuberant': 'exuberant',
#  'fat': 'fat',
#  'feminine': 'feminine',
#  'fennel': 'fennel',
#  'feral': 'feral',
#  'fig': 'fig',
#  'finegrained tannin': 'finegrained tannin',
#  'finessed': 'finessed',
#  'firm': 'firm',
#  'fizz': 'fizz',
#  'flabby': 'flabby',
#  'flashy': 'flashy',
#  'flat': 'flat',
#  'fleeting tannin': 'fleeting tannin',
#  'fleshy': 'fleshy',
#  'flint': 'flint',
#  'flower': 'flower',
#  'foamy': 'foamy',
#  'forest floor': 'forest floor',
#  'foxy': 'foxy',
#  'french oak': 'french oak',
#  'fresh': 'fresh',
#  'frothy': 'frothy',
#  'fruit': 'fruit',
#  'fruit-forward': 'fruit-forward',
#  'fruity': 'fruity',
#  'fudge': 'fudge',
#  'full bodied': 'full bodied',
#  'funky': 'funky',
#  'game': 'game',
#  'ginger': 'ginger',
#  'gingerbread': 'gingerbread',
#  'gold': 'gold',
#  'gooseberry': 'gooseberry',
#  'grabby': 'grabby',
#  'graham cracker': 'graham cracker',
#  'grain': 'grain',
#  'grainy': 'grainy',
#  'granite': 'granite',
#  'grapefruit': 'grapefruit',
#  'grapefruit peel': 'grapefruit peel',
#  'grapefruit pith': 'grapefruit pith',
#  'grapey': 'grapey',
#  'graphite': 'graphite',
#  'grass': 'grass',
#  'gravel': 'gravel',
#  'green': 'green',
#  'green banana': 'green banana',
#  'green bean': 'green bean',
#  'green fruit': 'green fruit',
#  'green pepper': 'green pepper',
#  'grilled herbs': 'grilled herbs',
#  'grilled meat': 'grilled meat',
#  'grilled peach': 'grilled peach',
#  'gripping': 'gripping',
#  'gripping tannin': 'gripping tannin',
#  'grippy': 'grippy',
#  'gritty': 'gritty',
#  'guava': 'guava',
#  'gummy': 'gummy',
#  'ham': 'ham',
#  'hard': 'hard',
#  'hay': 'hay',
#  'hazelnut': 'hazelnut',
#  'heady': 'heady',
#  'hearty': 'hearty',
#  'heavy': 'heavy',
#  'herb': 'herb',
#  'herbacious': 'herbacious',
#  'herbs': 'herbs',
#  'hibiscus': 'hibiscus',
#  'hickory': 'hickory',
#  'hickory smoke': 'hickory smoke',
#  'high acid': 'high acid',
#  'high alcohol': 'high alcohol',
#  'high tannin': 'high tannin',
#  'hollow': 'hollow',
#  'honey': 'honey',
#  'honeycomb': 'honeycomb',
#  'honeydew': 'honeydew',
#  'honeysuckle': 'honeysuckle',
#  'horsey': 'horsey',
#  'hot': 'hot',
#  'huckleberry': 'huckleberry',
#  'incense': 'incense',
#  'indian spice': 'indian spice',
#  'inky': 'inky',
#  'iodine': 'iodine',
#  'iron': 'iron',
#  'jagged': 'jagged',
#  'jalapeno': 'jalapeno',
#  'jam': 'jam',
#  'jasmine': 'jasmine',
#  'jelly': 'jelly',
#  'juicy': 'juicy',
#  'juniper': 'juniper',
#  'kirsch': 'kirsch',
#  'kiwi': 'kiwi',
#  'kumquat': 'kumquat',
#  'lactic': 'lactic',
#  'lanolin': 'lanolin',
#  'latex': 'latex',
#  'lavender': 'lavender',
#  'lavish': 'lavish',
#  'leafy': 'leafy',
#  'lean': 'lean',
#  'leather': 'leather',
#  'lees': 'lees',
#  'lemon': 'lemon',
#  'lemon blossom': 'lemon blossom',
#  'lemon curd': 'lemon curd',
#  'lemon custard': 'lemon custard',
#  'lemon drop': 'lemon drop',
#  'lemon meringue': 'lemon meringue',
#  'lemon peel': 'lemon peel',
#  'lemon pith': 'lemon pith',
#  'lemon verbena': 'lemon verbena',
#  'lemongrass': 'lemongrass',
#  'length': 'length',
#  'lengthy': 'lengthy',
#  'lettuce': 'lettuce',
#  'licorice': 'licorice',
#  'light': 'light',
#  'light bodied': 'light bodied',
#  'light color': 'light color',
#  'lilac': 'lilac',
#  'lime': 'lime',
#  'lime peel': 'lime peel',
#  'lime pith': 'lime pith',
#  'limestone': 'limestone',
#  'linear': 'linear',
#  'loamy': 'loamy',
#  'low acid': 'low acid',
#  'low alcohol': 'low alcohol',
#  'low complexity': 'low complexity',
#  'luminous': 'luminous',
#  'lush': 'lush',
#  'luxurious': 'luxurious',
#  'lychee': 'lychee',
#  'mace': 'mace',
#  'mandarin': 'mandarin',
#  'mango': 'mango',
#  'maple': 'maple',
#  'maple syrup': 'maple syrup',
#  'marjoram': 'marjoram',
#  'marmalade': 'marmalade',
#  'marshmallow': 'marshmallow',
#  'masculine': 'masculine',
#  'mass': 'mass',
#  'matchstick': 'matchstick',
#  'mealy': 'mealy',
#  'meat': 'meat',
#  'meaty': 'meaty',
#  'medicinal': 'medicinal',
#  'meditteranean herbs': 'meditteranean herbs',
#  'medium bodied': 'medium bodied',
#  'medium length finish': 'medium length finish',
#  'medium sweet': 'medium sweet',
#  'medium tannin': 'medium tannin',
#  'mellow': 'mellow',
#  'melon': 'melon',
#  'melon rind': 'melon rind',
#  'melted butter': 'melted butter',
#  'menthol': 'menthol',
#  'metal': 'metal',
#  'mild bitterness': 'mild bitterness',
#  'milk chocolate': 'milk chocolate',
#  'mineral': 'mineral',
#  'minerality': 'minerality',
#  'mint': 'mint',
#  'modest': 'modest',
#  'moist earth': 'moist earth',
#  'molasses': 'molasses',
#  'moss': 'moss',
#  'mousse': 'mousse',
#  'mulberry': 'mulberry',
#  'mulch': 'mulch',
#  'murky': 'murky',
#  'muscular': 'muscular',
#  'mushroom': 'mushroom',
#  'musky': 'musky',
#  'mustard': 'mustard',
#  'nectar': 'nectar',
#  'nectarine': 'nectarine',
#  'nervy': 'nervy',
#  'nettle': 'nettle',
#  'neutral oak': 'neutral oak',
#  'new oak': 'new oak',
#  'new wood': 'new wood',
#  'nut': 'nut',
#  'nutmeg': 'nutmeg',
#  'oak': 'oak',
#  'oak-driven': 'oak-driven',
#  'ocean': 'ocean',
#  'off-dry': 'off-dry',
#  'oil': 'oil',
#  'oily': 'oily',
#  'olallieberry': 'olallieberry',
#  'olive': 'olive',
#  'one dimensional': 'one dimensional',
#  'opulent': 'opulent',
#  'orange': 'orange',
#  'orange blossom': 'orange blossom',
#  'orange marmalade': 'orange marmalade',
#  'orange peel': 'orange peel',
#  'oregano': 'oregano',
#  'over-oaked': 'over-oaked',
#  'overripe': 'overripe',
#  'oxidized': 'oxidized',
#  'pale': 'pale',
#  'pale color': 'pale color',
#  'papaya': 'papaya',
#  'passion fruit': 'passion fruit',
#  'pastry': 'pastry',
#  'pea': 'pea',
#  'peach': 'peach',
#  'peach pit': 'peach pit',
#  'peanut': 'peanut',
#  'pear': 'pear',
#  'pencil lead': 'pencil lead',
#  'pencil shaving': 'pencil shaving',
#  'pepper': 'pepper',
#  'peppery': 'peppery',
#  'perfumed': 'perfumed',
#  'persimmon': 'persimmon',
#  'petal': 'petal',
#  'petrol': 'petrol',
#  'phenolic': 'phenolic',
#  'pickled': 'pickled',
#  'pie': 'pie',
#  'piercing': 'piercing',
#  'pillowy': 'pillowy',
#  'pine': 'pine',
#  'pineapple': 'pineapple',
#  'pink': 'pink',
#  'pink color': 'pink color',
#  'pith': 'pith',
#  'plastic': 'plastic',
#  'pleasant bitter': 'pleasant bitter',
#  'plum': 'plum',
#  'plump': 'plump',
#  'plush': 'plush',
#  'polished': 'polished',
#  'pollen': 'pollen',
#  'pomegranate': 'pomegranate',
#  'pop': 'pop',
#  'popcorn': 'popcorn',
#  'potpourri': 'potpourri',
#  'powdery': 'powdery',
#  'powerful': 'powerful',
#  'preserved lemon': 'preserved lemon',
#  'prickly': 'prickly',
#  'prune': 'prune',
#  'prune raisin': 'prune raisin',
#  'puckery': 'puckery',
#  'pulpy': 'pulpy',
#  'punchy': 'punchy',
#  'pungent': 'pungent',
#  'purple': 'purple',
#  'purple flower': 'purple flower',
#  'pyrazines': 'pyrazines',
#  'quaffer': 'quaffer',
#  'quince': 'quince',
#  'racy': 'racy',
#  'raisin': 'raisin',
#  'raisin prune': 'raisin prune',
#  'raspberry': 'raspberry',
#  'raspy': 'raspy',
#  'red berry': 'red berry',
#  'red currant': 'red currant',
#  'red fruit': 'red fruit',
#  'red plum': 'red plum',
#  'reductive': 'reductive',
#  'reedy': 'reedy',
#  'refined': 'refined',
#  'refreshing': 'refreshing',
#  'residual sugar': 'residual sugar',
#  'residual sweetness': 'residual sweetness',
#  'resin': 'resin',
#  'restrained': 'restrained',
#  'rhubarb': 'rhubarb',
#  'rich': 'rich',
#  'rind': 'rind',
#  'ripe': 'ripe',
#  'roast beef': 'roast beef',
#  'roasted almond': 'roasted almond',
#  'roasted meat': 'roasted meat',
#  'robust': 'robust',
#  'rocks': 'rocks',
#  'rocky': 'rocky',
#  'root': 'root',
#  'rose': 'rose',
#  'rose violet': 'rose violet',
#  'rosemary': 'rosemary',
#  'rosewater': 'rosewater',
#  'rough': 'rough',
#  'round': 'round',
#  'rubber': 'rubber',
#  'ruby color': 'ruby color',
#  'rum cake': 'rum cake',
#  'rustic': 'rustic',
#  'rusty': 'rusty',
#  'saddle leather': 'saddle leather',
#  'saffron': 'saffron',
#  'sage': 'sage',
#  'saline': 'saline',
#  'salt': 'salt',
#  'sandalwood': 'sandalwood',
#  'sanguine': 'sanguine',
#  'sappy': 'sappy',
#  'sassafras': 'sassafras',
#  'satiny': 'satiny',
#  'savory': 'savory',
#  'sawdust': 'sawdust',
#  'scorched earth': 'scorched earth',
#  'scratchy': 'scratchy',
#  'semisweet': 'semisweet',
#  'sharp': 'sharp',
#  'shimmer': 'shimmer',
#  'shine': 'shine',
#  'shoe polish': 'shoe polish',
#  'silky': 'silky',
#  'simple': 'simple',
#  'sinewy': 'sinewy',
#  'sizzling': 'sizzling',
#  'slate': 'slate',
#  'sleek': 'sleek',
#  'slick': 'slick',
#  'slightly sour': 'slightly sour',
#  'smoke': 'smoke',
#  'smoked bacon': 'smoked bacon',
#  'smoked meat': 'smoked meat',
#  'smoked nut': 'smoked nut',
#  'smoky': 'smoky',
#  'smooth': 'smooth',
#  'snappy': 'snappy',
#  'soapy': 'soapy',
#  'soft': 'soft',
#  'soil': 'soil',
#  'sorbet': 'sorbet',
#  'sour': 'sour',
#  'soy': 'soy',
#  'soy sauce': 'soy sauce',
#  'sparkling': 'sparkling',
#  'spearmint': 'spearmint',
#  'spice': 'spice',
#  'spice cake': 'spice cake',
#  'spiky': 'spiky',
#  'spring flower': 'spring flower',
#  'spritzy': 'spritzy',
#  'stalky': 'stalky',
#  'star anise': 'star anise',
#  'steak': 'steak',
#  'steel': 'steel',
#  'stemmy': 'stemmy',
#  'stewed plum': 'stewed plum',
#  'stewed prune': 'stewed prune',
#  'sticky': 'sticky',
#  'stone': 'stone',
#  'stone fruit': 'stone fruit',
#  'stout': 'stout',
#  'straw': 'straw',
#  'strawberry': 'strawberry',
#  'struck flint': 'struck flint',
#  'sturdy': 'sturdy',
#  'succulent': 'succulent',
#  'sugar': 'sugar',
#  'sulfur': 'sulfur',
#  'super rich': 'super rich',
#  'super ripe': 'super ripe',
#  'supple': 'supple',
#  'sweat': 'sweat',
#  'sweet': 'sweet',
#  'syrupy': 'syrupy',
#  'tangerine': 'tangerine',
#  'tangerine peel': 'tangerine peel',
#  'tangy': 'tangy',
#  'tannin': 'tannin',
#  'tar': 'tar',
#  'tarragon': 'tarragon',
#  'tart': 'tart',
#  'tea': 'tea',
#  'thick': 'thick',
#  'thyme': 'thyme',
#  'tight': 'tight',
#  'tingling': 'tingling',
#  'tingly': 'tingly',
#  'tire rubber': 'tire rubber',
#  'toast': 'toast',
#  'toasted almond': 'toasted almond',
#  'toasted coconut': 'toasted coconut',
#  'toasted hazelnut': 'toasted hazelnut',
#  'toasted nut': 'toasted nut',
#  'toasty oak': 'toasty oak',
#  'tobacco': 'tobacco',
#  'toffee': 'toffee',
#  'tomato': 'tomato',
#  'tree bark': 'tree bark',
#  'tree fruit': 'tree fruit',
#  'tropical fruit': 'tropical fruit',
#  'truffle': 'truffle',
#  'umami': 'umami',
#  'undergrowth': 'undergrowth',
#  'underripe': 'underripe',
#  'unoaked': 'unoaked',
#  'unripe': 'unripe',
#  'vanilla': 'vanilla',
#  'vanilla coconut': 'vanilla coconut',
#  'vanilla cream': 'vanilla cream',
#  'vanilla dill': 'vanilla dill',
#  'vegetal': 'vegetal',
#  'velvety': 'velvety',
#  'velvety tannin': 'velvety tannin',
#  'vibrant': 'vibrant',
#  'vinegar': 'vinegar',
#  'violet': 'violet',
#  'violet rose': 'violet rose',
#  'viscous': 'viscous',
#  'voluptuous': 'voluptuous',
#  'walnut': 'walnut',
#  'warm': 'warm',
#  'watermelon': 'watermelon',
#  'watery': 'watery',
#  'wax': 'wax',
#  'weed': 'weed',
#  'weight': 'weight',
#  'wet clay': 'wet clay',
#  'wet earth': 'wet earth',
#  'wet rocks': 'wet rocks',
#  'white': 'white',
#  'white almond': 'white almond',
#  'white blossom': 'white blossom',
#  'white currant': 'white currant',
#  'white flower': 'white flower',
#  'white fruit': 'white fruit',
#  'white pepper': 'white pepper',
#  'wild berry': 'wild berry',
#  'wild flower': 'wild flower',
#  'wildflower': 'wildflower',
#  'wood': 'wood',
#  'wood age': 'wood age',
#  'wood resin': 'wood resin',
#  'wood spice': 'wood spice',
#  'woody berry': 'woody berry',
#  'yeast': 'yeast',
#  'yellow': 'yellow',
#  'yellow flower': 'yellow flower',
#  'yellow fruit': 'yellow fruit',
#  'zest': 'zest',
#  'zesty': 'zesty',
#  'zingy': 'zingy',
#  'zippy': 'zippy'}

# %%
term_normalizer = RecipeNormalizer()
term_normalizer.read_and_write_ingredients(descriptors, './helpers/prep/wine_mapping_values.py', append_ingredients=False)
# Out:
# {'abrasive': 'abrasive',
#  'acacia': 'acacia',
#  'acid driven': 'acid driven',
#  'aggressive': 'aggressive',
#  'airy': 'airy',
#  'allspice': 'allspice',
#  'almond': 'almond',
#  'alpine herbs': 'alpine herbs',
#  'american oak': 'american oak',
#  'angular': 'angular',
#  'anise': 'anise',
#  'apple': 'apple',
#  'apple blossom': 'apple blossom',
#  'apple pie': 'apple pie',
#  'apple sauce': 'apple sauce',
#  'apricot': 'apricot',
#  'ash': 'ash',
#  'asian spice': 'asian spice',
#  'asparagus': 'asparagus',
#  'asphalt': 'asphalt',
#  'assertive': 'assertive',
#  'astringent': 'astringent',
#  'austere': 'austere',
#  'bacon': 'bacon',
#  'baked': 'baked',
#  'baked apple': 'baked apple',
#  'baked bread': 'baked bread',
#  'baking spices': 'baking spices',
#  'balsamic': 'balsamic',
#  'banana': 'banana',
#  'band-aid': 'band-aid',
#  'barbecue': 'barbecue',
#  'bark': 'bark',
#  'barnyard': 'barnyard',
#  'basil': 'basil',
#  'bay leaf': 'bay leaf',
#  'beef': 'beef',
#  'beef jerky': 'beef jerky',
#  'beefy': 'beefy',
#  'beeswax': 'beeswax',
#  'beet': 'beet',
#  'beetroot': 'beetroot',
#  'bell pepper': 'bell pepper',
#  'bergamot': 'bergamot',
#  'berry': 'berry',
#  'big-boned': 'big-boned',
#  'bite': 'bite',
#  'bitter': 'bitter',
#  'bitter almond': 'bitter almond',
#  'bittersweet': 'bittersweet',
#  'black cherry': 'black cherry',
#  'black currant': 'black currant',
#  'black fruit': 'black fruit',
#  'black pepper': 'black pepper',
#  'black tea': 'black tea',
#  'blackberry': 'blackberry',
#  'blackberry jam': 'blackberry jam',
#  'blackberry-cassis': 'blackberry-cassis',
#  'blackcurrant': 'blackcurrant',
#  'bland': 'bland',
#  'blood orange': 'blood orange',
#  'blossom': 'blossom',
#  'blue': 'blue',
#  'blue black': 'blue black',
#  'blue flower': 'blue flower',
#  'blue fruit': 'blue fruit',
#  'blueberry': 'blueberry',
#  'blueberry pie': 'blueberry pie',
#  'bold': 'bold',
#  'bone dry': 'bone dry',
#  'botrytis': 'botrytis',
#  'boysenberry': 'boysenberry',
#  'bramble': 'bramble',
#  'brawny': 'brawny',
#  'bread': 'bread',
#  'bread crust': 'bread crust',
#  'brick': 'brick',
#  'bright': 'bright',
#  'brilliant': 'brilliant',
#  'brine': 'brine',
#  'brioche': 'brioche',
#  'brisk': 'brisk',
#  'brown': 'brown',
#  'brown butter': 'brown butter',
#  'brown spice': 'brown spice',
#  'brown sugar': 'brown sugar',
#  'bubble gum': 'bubble gum',
#  'bubblegum': 'bubblegum',
#  'bulky': 'bulky',
#  'bullish': 'bullish',
#  'buoyant': 'buoyant',
#  'burnt': 'burnt',
#  'burnt toast': 'burnt toast',
#  'butter': 'butter',
#  'butter nut': 'butter nut',
#  'butter popcorn': 'butter popcorn',
#  'buttercream': 'buttercream',
#  'butterscotch': 'butterscotch',
#  'buttery toast': 'buttery toast',
#  'cake': 'cake',
#  'cake spice': 'cake spice',
#  'campfire': 'campfire',
#  'camphor': 'camphor',
#  'candle wax': 'candle wax',
#  'candy': 'candy',
#  'caramel': 'caramel',
#  'cardamom': 'cardamom',
#  'carob': 'carob',
#  'cashew': 'cashew',
#  'cassis': 'cassis',
#  'cataloupe': 'cataloupe',
#  'cedar': 'cedar',
#  'celery': 'celery',
#  'cement': 'cement',
#  'chalk': 'chalk',
#  'chamomile': 'chamomile',
#  'charcoal': 'charcoal',
#  'charred wood': 'charred wood',
#  'cheese': 'cheese',
#  'chemical': 'chemical',
#  'cherry': 'cherry',
#  'cherry liqueur': 'cherry liqueur',
#  'cherry pie': 'cherry pie',
#  'chewi': 'chewi',
#  'chocolate': 'chocolate',
#  'choppy': 'choppy',
#  'chunky': 'chunky',
#  'cider': 'cider',
#  'cigar': 'cigar',
#  'cigar box': 'cigar box',
#  'cinnamon': 'cinnamon',
#  'citrus': 'citrus',
#  'citrus acid': 'citrus acid',
#  'citrus peel': 'citrus peel',
#  'citrus pith': 'citrus pith',
#  'clampy': 'clampy',
#  'classy': 'classy',
#  'clay': 'clay',
#  'clean': 'clean',
#  'close-grained tannin': 'close-grained tannin',
#  'closed': 'closed',
#  'clove': 'clove',
#  'clove cinnamon': 'clove cinnamon',
#  'cloying': 'cloying',
#  'coarse': 'coarse',
#  'cocoa': 'cocoa',
#  'coconut': 'coconut',
#  'coffee': 'coffee',
#  'cola': 'cola',
#  'complex': 'complex',
#  'complicated': 'complicated',
#  'compost': 'compost',
#  'compote': 'compote',
#  'concentrated': 'concentrated',
#  'concrete': 'concrete',
#  'cooked': 'cooked',
#  'cooked spice': 'cooked spice',
#  'cookie': 'cookie',
#  'corn': 'corn',
#  'cotton candy': 'cotton candy',
#  'cracker': 'cracker',
#  'cranberry': 'cranberry',
#  'cranberry pomegranate': 'cranberry pomegranate',
#  'cream': 'cream',
#  'creamy': 'creamy',
#  'crisp': 'crisp',
#  'crunchy': 'crunchy',
#  'crème brulee': 'crème brulee',
#  'cucumber': 'cucumber',
#  'cured meat': 'cured meat',
#  'currant': 'currant',
#  'custard': 'custard',
#  'cut grass': 'cut grass',
#  'dainty': 'dainty',
#  'dark': 'dark',
#  'dark berry': 'dark berry',
#  'dark chocolate': 'dark chocolate',
#  'dark fruit': 'dark fruit',
#  'deep color': 'deep color',
#  'dense': 'dense',
#  'depth': 'depth',
#  'diesel': 'diesel',
#  'dill': 'dill',
#  'diluted': 'diluted',
#  'dr pepper': 'dr pepper',
#  'dried herb': 'dried herb',
#  'dry': 'dry',
#  'dull': 'dull',
#  'dust': 'dust',
#  'earth': 'earth',
#  'earthy': 'earthy',
#  'easy': 'easy',
#  'edgy': 'edgy',
#  'effervescent': 'effervescent',
#  'elderberry': 'elderberry',
#  'elderflower': 'elderflower',
#  'elegant': 'elegant',
#  'espresso': 'espresso',
#  'eucalyptus': 'eucalyptus',
#  'expansive': 'expansive',
#  'extracted': 'extracted',
#  'exuberant': 'exuberant',
#  'fat': 'fat',
#  'feminine': 'feminine',
#  'fennel': 'fennel',
#  'feral': 'feral',
#  'fig': 'fig',
#  'finegrained tannin': 'finegrained tannin',
#  'finessed': 'finessed',
#  'firm': 'firm',
#  'fizz': 'fizz',
#  'flabby': 'flabby',
#  'flashy': 'flashy',
#  'flat': 'flat',
#  'fleeting tannin': 'fleeting tannin',
#  'fleshy': 'fleshy',
#  'flint': 'flint',
#  'flower': 'flower',
#  'foamy': 'foamy',
#  'forest floor': 'forest floor',
#  'foxy': 'foxy',
#  'french oak': 'french oak',
#  'fresh': 'fresh',
#  'frothy': 'frothy',
#  'fruit': 'fruit',
#  'fruit-forward': 'fruit-forward',
#  'fruity': 'fruity',
#  'fudge': 'fudge',
#  'full bodied': 'full bodied',
#  'funky': 'funky',
#  'game': 'game',
#  'ginger': 'ginger',
#  'gingerbread': 'gingerbread',
#  'gold': 'gold',
#  'gooseberry': 'gooseberry',
#  'grabby': 'grabby',
#  'graham cracker': 'graham cracker',
#  'grain': 'grain',
#  'grainy': 'grainy',
#  'granite': 'granite',
#  'grapefruit': 'grapefruit',
#  'grapefruit peel': 'grapefruit peel',
#  'grapefruit pith': 'grapefruit pith',
#  'grapey': 'grapey',
#  'graphite': 'graphite',
#  'grass': 'grass',
#  'gravel': 'gravel',
#  'green': 'green',
#  'green banana': 'green banana',
#  'green bean': 'green bean',
#  'green fruit': 'green fruit',
#  'green pepper': 'green pepper',
#  'grilled herbs': 'grilled herbs',
#  'grilled meat': 'grilled meat',
#  'grilled peach': 'grilled peach',
#  'gripping': 'gripping',
#  'gripping tannin': 'gripping tannin',
#  'grippy': 'grippy',
#  'gritty': 'gritty',
#  'guava': 'guava',
#  'gummy': 'gummy',
#  'ham': 'ham',
#  'hard': 'hard',
#  'hay': 'hay',
#  'hazelnut': 'hazelnut',
#  'heady': 'heady',
#  'hearty': 'hearty',
#  'heavy': 'heavy',
#  'herb': 'herb',
#  'herbacious': 'herbacious',
#  'herbs': 'herbs',
#  'hibiscus': 'hibiscus',
#  'hickory': 'hickory',
#  'hickory smoke': 'hickory smoke',
#  'high acid': 'high acid',
#  'high alcohol': 'high alcohol',
#  'high tannin': 'high tannin',
#  'hollow': 'hollow',
#  'honey': 'honey',
#  'honeycomb': 'honeycomb',
#  'honeydew': 'honeydew',
#  'honeysuckle': 'honeysuckle',
#  'horsey': 'horsey',
#  'hot': 'hot',
#  'huckleberry': 'huckleberry',
#  'incense': 'incense',
#  'indian spice': 'indian spice',
#  'inky': 'inky',
#  'iodine': 'iodine',
#  'iron': 'iron',
#  'jagged': 'jagged',
#  'jalapeno': 'jalapeno',
#  'jam': 'jam',
#  'jasmine': 'jasmine',
#  'jelly': 'jelly',
#  'juicy': 'juicy',
#  'juniper': 'juniper',
#  'kirsch': 'kirsch',
#  'kiwi': 'kiwi',
#  'kumquat': 'kumquat',
#  'lactic': 'lactic',
#  'lanolin': 'lanolin',
#  'latex': 'latex',
#  'lavender': 'lavender',
#  'lavish': 'lavish',
#  'leafy': 'leafy',
#  'lean': 'lean',
#  'leather': 'leather',
#  'lees': 'lees',
#  'lemon': 'lemon',
#  'lemon blossom': 'lemon blossom',
#  'lemon curd': 'lemon curd',
#  'lemon custard': 'lemon custard',
#  'lemon drop': 'lemon drop',
#  'lemon meringue': 'lemon meringue',
#  'lemon peel': 'lemon peel',
#  'lemon pith': 'lemon pith',
#  'lemon verbena': 'lemon verbena',
#  'lemongrass': 'lemongrass',
#  'length': 'length',
#  'lengthy': 'lengthy',
#  'lettuce': 'lettuce',
#  'licorice': 'licorice',
#  'light': 'light',
#  'light bodied': 'light bodied',
#  'light color': 'light color',
#  'lilac': 'lilac',
#  'lime': 'lime',
#  'lime peel': 'lime peel',
#  'lime pith': 'lime pith',
#  'limestone': 'limestone',
#  'linear': 'linear',
#  'loamy': 'loamy',
#  'low acid': 'low acid',
#  'low alcohol': 'low alcohol',
#  'low complexity': 'low complexity',
#  'luminous': 'luminous',
#  'lush': 'lush',
#  'luxurious': 'luxurious',
#  'lychee': 'lychee',
#  'mace': 'mace',
#  'mandarin': 'mandarin',
#  'mango': 'mango',
#  'maple': 'maple',
#  'maple syrup': 'maple syrup',
#  'marjoram': 'marjoram',
#  'marmalade': 'marmalade',
#  'marshmallow': 'marshmallow',
#  'masculine': 'masculine',
#  'mass': 'mass',
#  'matchstick': 'matchstick',
#  'mealy': 'mealy',
#  'meat': 'meat',
#  'meaty': 'meaty',
#  'medicinal': 'medicinal',
#  'meditteranean herbs': 'meditteranean herbs',
#  'medium bodied': 'medium bodied',
#  'medium length finish': 'medium length finish',
#  'medium sweet': 'medium sweet',
#  'medium tannin': 'medium tannin',
#  'mellow': 'mellow',
#  'melon': 'melon',
#  'melon rind': 'melon rind',
#  'melted butter': 'melted butter',
#  'menthol': 'menthol',
#  'metal': 'metal',
#  'mild bitterness': 'mild bitterness',
#  'milk chocolate': 'milk chocolate',
#  'mineral': 'mineral',
#  'minerality': 'minerality',
#  'mint': 'mint',
#  'modest': 'modest',
#  'moist earth': 'moist earth',
#  'molasses': 'molasses',
#  'moss': 'moss',
#  'mousse': 'mousse',
#  'mulberry': 'mulberry',
#  'mulch': 'mulch',
#  'murky': 'murky',
#  'muscular': 'muscular',
#  'mushroom': 'mushroom',
#  'musky': 'musky',
#  'mustard': 'mustard',
#  'nectar': 'nectar',
#  'nectarine': 'nectarine',
#  'nervy': 'nervy',
#  'nettle': 'nettle',
#  'neutral oak': 'neutral oak',
#  'new oak': 'new oak',
#  'new wood': 'new wood',
#  'nut': 'nut',
#  'nutmeg': 'nutmeg',
#  'oak': 'oak',
#  'oak-driven': 'oak-driven',
#  'ocean': 'ocean',
#  'off-dry': 'off-dry',
#  'oil': 'oil',
#  'oily': 'oily',
#  'olallieberry': 'olallieberry',
#  'olive': 'olive',
#  'one dimensional': 'one dimensional',
#  'opulent': 'opulent',
#  'orange': 'orange',
#  'orange blossom': 'orange blossom',
#  'orange marmalade': 'orange marmalade',
#  'orange peel': 'orange peel',
#  'oregano': 'oregano',
#  'over-oaked': 'over-oaked',
#  'overripe': 'overripe',
#  'oxidized': 'oxidized',
#  'pale': 'pale',
#  'pale color': 'pale color',
#  'papaya': 'papaya',
#  'passion fruit': 'passion fruit',
#  'pastry': 'pastry',
#  'pea': 'pea',
#  'peach': 'peach',
#  'peach pit': 'peach pit',
#  'peanut': 'peanut',
#  'pear': 'pear',
#  'pencil lead': 'pencil lead',
#  'pencil shaving': 'pencil shaving',
#  'pepper': 'pepper',
#  'peppery': 'peppery',
#  'perfumed': 'perfumed',
#  'persimmon': 'persimmon',
#  'petal': 'petal',
#  'petrol': 'petrol',
#  'phenolic': 'phenolic',
#  'pickled': 'pickled',
#  'pie': 'pie',
#  'piercing': 'piercing',
#  'pillowy': 'pillowy',
#  'pine': 'pine',
#  'pineapple': 'pineapple',
#  'pink': 'pink',
#  'pink color': 'pink color',
#  'pith': 'pith',
#  'plastic': 'plastic',
#  'pleasant bitter': 'pleasant bitter',
#  'plum': 'plum',
#  'plump': 'plump',
#  'plush': 'plush',
#  'polished': 'polished',
#  'pollen': 'pollen',
#  'pomegranate': 'pomegranate',
#  'pop': 'pop',
#  'popcorn': 'popcorn',
#  'potpourri': 'potpourri',
#  'powdery': 'powdery',
#  'powerful': 'powerful',
#  'preserved lemon': 'preserved lemon',
#  'prickly': 'prickly',
#  'prune': 'prune',
#  'prune raisin': 'prune raisin',
#  'puckery': 'puckery',
#  'pulpy': 'pulpy',
#  'punchy': 'punchy',
#  'pungent': 'pungent',
#  'purple': 'purple',
#  'purple flower': 'purple flower',
#  'pyrazines': 'pyrazines',
#  'quaffer': 'quaffer',
#  'quince': 'quince',
#  'racy': 'racy',
#  'raisin': 'raisin',
#  'raisin prune': 'raisin prune',
#  'raspberry': 'raspberry',
#  'raspy': 'raspy',
#  'red berry': 'red berry',
#  'red currant': 'red currant',
#  'red fruit': 'red fruit',
#  'red plum': 'red plum',
#  'reductive': 'reductive',
#  'reedy': 'reedy',
#  'refined': 'refined',
#  'refreshing': 'refreshing',
#  'residual sugar': 'residual sugar',
#  'residual sweetness': 'residual sweetness',
#  'resin': 'resin',
#  'restrained': 'restrained',
#  'rhubarb': 'rhubarb',
#  'rich': 'rich',
#  'rind': 'rind',
#  'ripe': 'ripe',
#  'roast beef': 'roast beef',
#  'roasted almond': 'roasted almond',
#  'roasted meat': 'roasted meat',
#  'robust': 'robust',
#  'rocks': 'rocks',
#  'rocky': 'rocky',
#  'root': 'root',
#  'rose': 'rose',
#  'rose violet': 'rose violet',
#  'rosemary': 'rosemary',
#  'rosewater': 'rosewater',
#  'rough': 'rough',
#  'round': 'round',
#  'rubber': 'rubber',
#  'ruby color': 'ruby color',
#  'rum cake': 'rum cake',
#  'rustic': 'rustic',
#  'rusty': 'rusty',
#  'saddle leather': 'saddle leather',
#  'saffron': 'saffron',
#  'sage': 'sage',
#  'saline': 'saline',
#  'salt': 'salt',
#  'sandalwood': 'sandalwood',
#  'sanguine': 'sanguine',
#  'sappy': 'sappy',
#  'sassafras': 'sassafras',
#  'satiny': 'satiny',
#  'savory': 'savory',
#  'sawdust': 'sawdust',
#  'scorched earth': 'scorched earth',
#  'scratchy': 'scratchy',
#  'semisweet': 'semisweet',
#  'sharp': 'sharp',
#  'shimmer': 'shimmer',
#  'shine': 'shine',
#  'shoe polish': 'shoe polish',
#  'silky': 'silky',
#  'simple': 'simple',
#  'sinewy': 'sinewy',
#  'sizzling': 'sizzling',
#  'slate': 'slate',
#  'sleek': 'sleek',
#  'slick': 'slick',
#  'slightly sour': 'slightly sour',
#  'smoke': 'smoke',
#  'smoked bacon': 'smoked bacon',
#  'smoked meat': 'smoked meat',
#  'smoked nut': 'smoked nut',
#  'smoky': 'smoky',
#  'smooth': 'smooth',
#  'snappy': 'snappy',
#  'soapy': 'soapy',
#  'soft': 'soft',
#  'soil': 'soil',
#  'sorbet': 'sorbet',
#  'sour': 'sour',
#  'soy': 'soy',
#  'soy sauce': 'soy sauce',
#  'sparkling': 'sparkling',
#  'spearmint': 'spearmint',
#  'spice': 'spice',
#  'spice cake': 'spice cake',
#  'spiky': 'spiky',
#  'spring flower': 'spring flower',
#  'spritzy': 'spritzy',
#  'stalky': 'stalky',
#  'star anise': 'star anise',
#  'steak': 'steak',
#  'steel': 'steel',
#  'stemmy': 'stemmy',
#  'stewed plum': 'stewed plum',
#  'stewed prune': 'stewed prune',
#  'sticky': 'sticky',
#  'stone': 'stone',
#  'stone fruit': 'stone fruit',
#  'stout': 'stout',
#  'straw': 'straw',
#  'strawberry': 'strawberry',
#  'struck flint': 'struck flint',
#  'sturdy': 'sturdy',
#  'succulent': 'succulent',
#  'sugar': 'sugar',
#  'sulfur': 'sulfur',
#  'super rich': 'super rich',
#  'super ripe': 'super ripe',
#  'supple': 'supple',
#  'sweat': 'sweat',
#  'sweet': 'sweet',
#  'syrupy': 'syrupy',
#  'tangerine': 'tangerine',
#  'tangerine peel': 'tangerine peel',
#  'tangy': 'tangy',
#  'tannin': 'tannin',
#  'tar': 'tar',
#  'tarragon': 'tarragon',
#  'tart': 'tart',
#  'tea': 'tea',
#  'thick': 'thick',
#  'thyme': 'thyme',
#  'tight': 'tight',
#  'tingling': 'tingling',
#  'tingly': 'tingly',
#  'tire rubber': 'tire rubber',
#  'toast': 'toast',
#  'toasted almond': 'toasted almond',
#  'toasted coconut': 'toasted coconut',
#  'toasted hazelnut': 'toasted hazelnut',
#  'toasted nut': 'toasted nut',
#  'toasty oak': 'toasty oak',
#  'tobacco': 'tobacco',
#  'toffee': 'toffee',
#  'tomato': 'tomato',
#  'tree bark': 'tree bark',
#  'tree fruit': 'tree fruit',
#  'tropical fruit': 'tropical fruit',
#  'truffle': 'truffle',
#  'umami': 'umami',
#  'undergrowth': 'undergrowth',
#  'underripe': 'underripe',
#  'unoaked': 'unoaked',
#  'unripe': 'unripe',
#  'vanilla': 'vanilla',
#  'vanilla coconut': 'vanilla coconut',
#  'vanilla cream': 'vanilla cream',
#  'vanilla dill': 'vanilla dill',
#  'vegetal': 'vegetal',
#  'velvety': 'velvety',
#  'velvety tannin': 'velvety tannin',
#  'vibrant': 'vibrant',
#  'vinegar': 'vinegar',
#  'violet': 'violet',
#  'violet rose': 'violet rose',
#  'viscous': 'viscous',
#  'voluptuous': 'voluptuous',
#  'walnut': 'walnut',
#  'warm': 'warm',
#  'watermelon': 'watermelon',
#  'watery': 'watery',
#  'wax': 'wax',
#  'weed': 'weed',
#  'weight': 'weight',
#  'wet clay': 'wet clay',
#  'wet earth': 'wet earth',
#  'wet rocks': 'wet rocks',
#  'white': 'white',
#  'white almond': 'white almond',
#  'white blossom': 'white blossom',
#  'white currant': 'white currant',
#  'white flower': 'white flower',
#  'white fruit': 'white fruit',
#  'white pepper': 'white pepper',
#  'wild berry': 'wild berry',
#  'wild flower': 'wild flower',
#  'wildflower': 'wildflower',
#  'wood': 'wood',
#  'wood age': 'wood age',
#  'wood resin': 'wood resin',
#  'wood spice': 'wood spice',
#  'woody berry': 'woody berry',
#  'yeast': 'yeast',
#  'yellow': 'yellow',
#  'yellow flower': 'yellow flower',
#  'yellow fruit': 'yellow fruit',
#  'zest': 'zest',
#  'zesty': 'zesty',
#  'zingy': 'zingy',
#  'zippy': 'zippy'}
